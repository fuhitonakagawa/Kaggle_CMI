# %% [markdown]
# **If you support the notebook, please upvote—I’d really appreciate it!**
# **Also, if you have any questions, feel free to ask—I’ll be happy to answer. 😊**
# ### UPDATE: Enhanced IMU Signal Processing with Gravity Removal & Dataset Split Adjustment
#
# This version builds upon the enhancements from my previous notebook: **[LB 0.76 | IMU+THM/TOF | TF BiLSTM+GRU+Attention](https://www.kaggle.com/code/rktqwe/lb-0-76-imu-thm-tof-tf-bilstm-gru-attention)**. The key changes in *this* update are:
#
# 1.  **Gravity Component Removal from Accelerometer Data (Key Improvement):**
#     *   **Purpose:** Raw accelerometer data measures both the device's linear acceleration (actual movement) and the constant pull of gravity. By isolating the linear acceleration, we aim to provide the model with cleaner, more motion-specific signals, potentially improving its ability to distinguish between subtle gestures.
#     *   **Method:**
#         *   We utilize quaternion rotation data (`rot_x`, `rot_y`, `rot_z`, `rot_w`) to determine the device's orientation in 3D space.
#         *   Using `scipy.spatial.transform.Rotation`, we project a standard gravity vector (`[0, 0, 9.81] m/s²`) from the world frame into the sensor's coordinate frame for each timestamp.
#         *   This estimated gravity component in the sensor's frame is then subtracted from the raw `acc_x`, `acc_y`, `acc_z` readings.
#     *   **New Features Derived:**
#         *   `linear_acc_x`, `linear_acc_y`, `linear_acc_z`: Accelerometer readings with gravity removed. These now form the base acceleration features.
#         *   `linear_acc_mag`: Magnitude of the linear acceleration.
#         *   `linear_acc_mag_jerk`: Derivative (jerk) of the linear acceleration magnitude.
#     *   **Impact:** The `imu_cols_base` now uses these `linear_acc_x/y/z` features instead of the raw `acc_x/y/z`. The original `acc_mag` (which includes gravity) is retained as it might still offer complementary information.
#
# 2.  **Train/Validation Split Adjustment:**
#     *   The `train_test_split` ratio for creating training and validation sets was changed from `test_size=0.1` (90% train, 10% validation) to `test_size=0.2` (80% train, 20% validation). This provides a larger validation set for more robust evaluation during training.
#
#
#
# **This solution was developed by building upon the foundational work of two key contributors:**
#
# - **CMI25 | IMU+THM/TOF |TF BiLSTM+GRU+Attention|LB.75** by [yukiZ](https://www.kaggle.com/code/hideyukizushi/cmi25-imu-thm-tof-tf-bilstm-gru-attention-lb-75)
# - **imu-tof** by [Erich von Mainstein](https://www.kaggle.com/code/vonmainstein/imu-tof)
#
# **Special recognition for the exceptional exploratory data analysis:**
#
# - **Sensor Pulse🧠| Viz & EDA for BFRB Detection** by [Tarun Mishra](https://www.kaggle.com/code/tarundirector/sensor-pulse-viz-eda-for-bfrb-detection)
#
# ### Implemented Enhancements
#
# #### 1. IMU Signal Processing Optimization (Core Improvement)
#
# **Implemented Features:**
# - Derived kinematic metrics:
#   - Acceleration vector magnitude (`acc_mag`)
#   - Scalar rotation angle (`rot_angle`)
#   - Acceleration derivative (`acc_mag_jerk`)
#   - Angular velocity (`rot_angle_vel`)
# - Initial learning rate reduction from `1e-3` to `5e-4`
# - Implemented cosine decay scheduling:
#   - Parameters: `first_decay_steps = 15 × steps_per_epoch`
#
# **Unsuccessful Experiments (Reverted):**
# - Further LR Reduction: `LR_INIT = 2-e4` worsened score.
# - Dropout Rate Adjustments: No improvement over baseline dropout.
# - TOF/THEM Branch Architecture Change: Replacing simpler CNNs with `residual_se_cnn_blocks` was detrimental.

# %% [markdown]
# ### 》》》**Importing the necessary Libraries**

# %%
import os, json, joblib, numpy as np, pandas as pd
from pathlib import Path
import warnings 
warnings.filterwarnings("ignore")


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils.class_weight import compute_class_weight

from tensorflow.keras.utils import Sequence, to_categorical, pad_sequences
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization, Activation, add, MaxPooling1D, Dropout,
    Bidirectional, LSTM, GlobalAveragePooling1D, Dense, Multiply, Reshape,
    Lambda, Concatenate, GRU, GaussianNoise
)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as K
import tensorflow as tf
import polars as pl
from sklearn.model_selection import StratifiedGroupKFold
from scipy.spatial.transform import Rotation as R
# Out:
# 2025-06-18 19:11:41.349285: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750273901.522643      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750273901.582157      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ### 》》》**Fix Seed**

# %%
import random
def seed_everything(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    tf.experimental.numpy.random.seed(seed)
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
seed_everything(seed=42)

# %% [markdown]
# ### 》》》**Configuration**

# %%
# (Competition metric will only be imported when TRAINing)
TRAIN = True                     # ← set to True when you want to train
RAW_DIR = Path("/kaggle/input/cmi-detect-behavior-with-sensor-data")
PRETRAINED_DIR = Path("/kaggle/input/pretrained-model")  # used when TRAIN=False
EXPORT_DIR = Path("./")                                    # artefacts will be saved here
BATCH_SIZE = 64
PAD_PERCENTILE = 95
LR_INIT = 5e-4
WD = 3e-3
MIXUP_ALPHA = 0.4
EPOCHS = 160
PATIENCE = 40


print("▶ imports ready · tensorflow", tf.__version__)
# Out:
# ▶ imports ready · tensorflow 2.18.0

# %% [markdown]
# ### 》》》**Utility Functions**

# %%
#Tensor Manipulations
def time_sum(x):
    return K.sum(x, axis=1)

def squeeze_last_axis(x):
    return tf.squeeze(x, axis=-1)

def expand_last_axis(x):
    return tf.expand_dims(x, axis=-1)

def se_block(x, reduction=8):
    ch = x.shape[-1]
    se = GlobalAveragePooling1D()(x)
    se = Dense(ch // reduction, activation='relu')(se)
    se = Dense(ch, activation='sigmoid')(se)
    se = Reshape((1, ch))(se)
    return Multiply()([x, se])

# Residual CNN Block with SE
def residual_se_cnn_block(x, filters, kernel_size, pool_size=2, drop=0.3, wd=1e-4):
    shortcut = x
    for _ in range(2):
        x = Conv1D(filters, kernel_size, padding='same', use_bias=False,
                   kernel_regularizer=l2(wd))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
    x = se_block(x)
    if shortcut.shape[-1] != filters:
        shortcut = Conv1D(filters, 1, padding='same', use_bias=False,
                          kernel_regularizer=l2(wd))(shortcut)
        shortcut = BatchNormalization()(shortcut)
    x = add([x, shortcut])
    x = Activation('relu')(x)
    x = MaxPooling1D(pool_size)(x)
    x = Dropout(drop)(x)
    return x

def attention_layer(inputs):
    score = Dense(1, activation='tanh')(inputs)
    score = Lambda(squeeze_last_axis)(score)
    weights = Activation('softmax')(score)
    weights = Lambda(expand_last_axis)(weights)
    context = Multiply()([inputs, weights])
    context = Lambda(time_sum)(context)
    return context

# %% [markdown]
# ### 》》》**Data Helpers**

# %%
# Normalizes and cleans the time series sequence. 

def preprocess_sequence(df_seq: pd.DataFrame, feature_cols: list[str], scaler: StandardScaler):
    mat = df_seq[feature_cols].ffill().bfill().fillna(0).values
    return scaler.transform(mat).astype('float32')

# MixUp the data argumentation in order to regularize the neural network. 

class MixupGenerator(Sequence):
    def __init__(self, X, y, batch_size, alpha=0.2):
        self.X, self.y = X, y
        self.batch = batch_size
        self.alpha = alpha
        self.indices = np.arange(len(X))
    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch))
    def __getitem__(self, i):
        idx = self.indices[i*self.batch:(i+1)*self.batch]
        Xb, yb = self.X[idx], self.y[idx]
        lam = np.random.beta(self.alpha, self.alpha)
        perm = np.random.permutation(len(Xb))
        X_mix = lam * Xb + (1-lam) * Xb[perm]
        y_mix = lam * yb + (1-lam) * yb[perm]
        return X_mix, y_mix
    def on_epoch_end(self):
        np.random.shuffle(self.indices)

# %%
def remove_gravity_from_acc(acc_data, rot_data):

    if isinstance(acc_data, pd.DataFrame):
        acc_values = acc_data[['acc_x', 'acc_y', 'acc_z']].values
    else:
        acc_values = acc_data

    if isinstance(rot_data, pd.DataFrame):
        quat_values = rot_data[['rot_x', 'rot_y', 'rot_z', 'rot_w']].values
    else:
        quat_values = rot_data

    num_samples = acc_values.shape[0]
    linear_accel = np.zeros_like(acc_values)
    
    gravity_world = np.array([0, 0, 9.81])

    for i in range(num_samples):
        if np.all(np.isnan(quat_values[i])) or np.all(np.isclose(quat_values[i], 0)):
            linear_accel[i, :] = acc_values[i, :] 
            continue

        try:
            rotation = R.from_quat(quat_values[i])
            gravity_sensor_frame = rotation.apply(gravity_world, inverse=True)
            linear_accel[i, :] = acc_values[i, :] - gravity_sensor_frame
        except ValueError:
             linear_accel[i, :] = acc_values[i, :]
             
    return linear_accel

# %% [markdown]
# ### 》》》**Model Definition - Two Branch Architecture**

# %%
def build_two_branch_model(pad_len, imu_dim, tof_dim, n_classes, wd=1e-4):
    inp = Input(shape=(pad_len, imu_dim+tof_dim))
    imu = Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # IMU deep branch
    x1 = residual_se_cnn_block(imu, 64, 3, drop=0.1, wd=wd)
    x1 = residual_se_cnn_block(x1, 128, 5, drop=0.1, wd=wd)

    # TOF/Thermal lighter branch
    x2 = Conv1D(64, 3, padding='same', use_bias=False, kernel_regularizer=l2(wd))(tof)
    x2 = BatchNormalization()(x2); x2 = Activation('relu')(x2)
    x2 = MaxPooling1D(2)(x2); x2 = Dropout(0.2)(x2)
    x2 = Conv1D(128, 3, padding='same', use_bias=False, kernel_regularizer=l2(wd))(x2)
    x2 = BatchNormalization()(x2); x2 = Activation('relu')(x2)
    x2 = MaxPooling1D(2)(x2); x2 = Dropout(0.2)(x2)

    merged = Concatenate()([x1, x2])

    xa = Bidirectional(LSTM(128, return_sequences=True, kernel_regularizer=l2(wd)))(merged)
    xb = Bidirectional(GRU(128, return_sequences=True, kernel_regularizer=l2(wd)))(merged)
    xc = GaussianNoise(0.09)(merged)
    xc = Dense(16, activation='elu')(xc)
    
    x = Concatenate()([xa, xb, xc])
    x = Dropout(0.4)(x)
    x = attention_layer(x)

    for units, drop in [(256, 0.5), (128, 0.3)]:
        x = Dense(units, use_bias=False, kernel_regularizer=l2(wd))(x)
        x = BatchNormalization()(x); x = Activation('relu')(x)
        x = Dropout(drop)(x)

    out = Dense(n_classes, activation='softmax', kernel_regularizer=l2(wd))(x)
    return Model(inp, out)

tmp_model = build_two_branch_model(127,7,325,18)
# Out:
# I0000 00:00:1750273914.597946      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %% [markdown]
# ### 》》》**Training / Inference Pipeline**

# %%
if TRAIN:
    print("▶ TRAIN MODE – loading dataset …")
    df = pd.read_csv(RAW_DIR / "train.csv")

    train_dem_df = pd.read_csv(RAW_DIR / "train_demographics.csv")
    df_for_groups = pd.merge(df.copy(), train_dem_df, on='subject', how='left')

    le = LabelEncoder()
    df['gesture_int'] = le.fit_transform(df['gesture'])
    np.save(EXPORT_DIR / "gesture_classes.npy", le.classes_)
    gesture_classes = le.classes_

    print("  Calculating base engineered IMU features (magnitude, angle)...")
    df['acc_mag'] = np.sqrt(df['acc_x']**2 + df['acc_y']**2 + df['acc_z']**2)
    df['rot_angle'] = 2 * np.arccos(df['rot_w'].clip(-1, 1))
    
    print("  Calculating engineered IMU derivatives (jerk, angular velocity) for original acc_mag...")
    df['acc_mag_jerk'] = df.groupby('sequence_id')['acc_mag'].diff().fillna(0)
    df['rot_angle_vel'] = df.groupby('sequence_id')['rot_angle'].diff().fillna(0)

    print("  Removing gravity and calculating linear acceleration features...")
    
    linear_accel_list = []
    for _, group in df.groupby('sequence_id'):
        acc_data_group = group[['acc_x', 'acc_y', 'acc_z']]
        rot_data_group = group[['rot_x', 'rot_y', 'rot_z', 'rot_w']]
        linear_accel_group = remove_gravity_from_acc(acc_data_group, rot_data_group)
        linear_accel_list.append(pd.DataFrame(linear_accel_group, columns=['linear_acc_x', 'linear_acc_y', 'linear_acc_z'], index=group.index))
    
    df_linear_accel = pd.concat(linear_accel_list)
    df = pd.concat([df, df_linear_accel], axis=1)

    df['linear_acc_mag'] = np.sqrt(df['linear_acc_x']**2 + df['linear_acc_y']**2 + df['linear_acc_z']**2)
    df['linear_acc_mag_jerk'] = df.groupby('sequence_id')['linear_acc_mag'].diff().fillna(0)

    meta_cols = { ... }

    imu_cols_base = ['linear_acc_x', 'linear_acc_y', 'linear_acc_z']
    imu_cols_base.extend([c for c in df.columns if c.startswith('rot_') and c not in ['rot_angle', 'rot_angle_vel']])
    
    imu_engineered_features = [
        'acc_mag', 'rot_angle',
        'acc_mag_jerk', 'rot_angle_vel',
        'linear_acc_mag', 'linear_acc_mag_jerk'
    ]
    imu_cols = imu_cols_base + imu_engineered_features
    imu_cols = list(dict.fromkeys(imu_cols))

    thm_cols_original = [c for c in df.columns if c.startswith('thm_')]
    
    tof_aggregated_cols_template = []
    for i in range(1, 6):
        tof_aggregated_cols_template.extend([f'tof_{i}_mean', f'tof_{i}_std', f'tof_{i}_min', f'tof_{i}_max'])

    final_feature_cols = imu_cols + thm_cols_original + tof_aggregated_cols_template
    imu_dim_final = len(imu_cols)
    tof_thm_aggregated_dim_final = len(thm_cols_original) + len(tof_aggregated_cols_template)
    
    print(f"  IMU (incl. engineered & derivatives) {imu_dim_final} | THM + Aggregated TOF {tof_thm_aggregated_dim_final} | total {len(final_feature_cols)} features")
    np.save(EXPORT_DIR / "feature_cols.npy", np.array(final_feature_cols))

    print("  Building sequences with aggregated TOF and preparing data for scaler...")
    seq_gp = df.groupby('sequence_id') 
    
    all_steps_for_scaler_list = []
    X_list_unscaled, y_list_int_for_stratify, lens = [], [], [] 

    for seq_id, seq_df_orig in seq_gp:
        seq_df = seq_df_orig.copy()

        for i in range(1, 6):
            pixel_cols_tof = [f"tof_{i}_v{p}" for p in range(64)]
            tof_sensor_data = seq_df[pixel_cols_tof].replace(-1, np.nan)
            seq_df[f'tof_{i}_mean'] = tof_sensor_data.mean(axis=1)
            seq_df[f'tof_{i}_std']  = tof_sensor_data.std(axis=1)
            seq_df[f'tof_{i}_min']  = tof_sensor_data.min(axis=1)
            seq_df[f'tof_{i}_max']  = tof_sensor_data.max(axis=1)
        
        mat_unscaled = seq_df[final_feature_cols].ffill().bfill().fillna(0).values.astype('float32')
        
        all_steps_for_scaler_list.append(mat_unscaled)
        X_list_unscaled.append(mat_unscaled)
        y_list_int_for_stratify.append(seq_df['gesture_int'].iloc[0])
        lens.append(len(mat_unscaled))

    print("  Fitting StandardScaler...")
    all_steps_concatenated = np.concatenate(all_steps_for_scaler_list, axis=0)
    scaler = StandardScaler().fit(all_steps_concatenated)
    joblib.dump(scaler, EXPORT_DIR / "scaler.pkl")
    del all_steps_for_scaler_list, all_steps_concatenated

    print("  Scaling and padding sequences...")
    X_scaled_list = [scaler.transform(x_seq) for x_seq in X_list_unscaled]
    del X_list_unscaled

    pad_len = int(np.percentile(lens, PAD_PERCENTILE))
    np.save(EXPORT_DIR / "sequence_maxlen.npy", pad_len)
    
    X = pad_sequences(X_scaled_list, maxlen=pad_len, padding='post', truncating='post', dtype='float32')
    del X_scaled_list
    
    y_int_for_stratify = np.array(y_list_int_for_stratify)
    y = to_categorical(y_int_for_stratify, num_classes=len(le.classes_))

    print("  Splitting data and preparing for training...")
    X_tr, X_val, y_tr, y_val = train_test_split(X, y, test_size=0.2, random_state=82, stratify=y_int_for_stratify)

    cw_vals = compute_class_weight('balanced', classes=np.arange(len(le.classes_)), y=y_int_for_stratify)
    class_weight = dict(enumerate(cw_vals))

    model = build_two_branch_model(pad_len, imu_dim_final, tof_thm_aggregated_dim_final, len(le.classes_), wd=WD)
    
    steps = len(X_tr) // BATCH_SIZE
    lr_sched = tf.keras.optimizers.schedules.CosineDecayRestarts(5e-4, first_decay_steps=15 * steps) 
    
    model.compile(optimizer=Adam(lr_sched),
                  loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])

    train_gen = MixupGenerator(X_tr, y_tr, batch_size=BATCH_SIZE, alpha=MIXUP_ALPHA)
    cb = EarlyStopping(patience=PATIENCE, restore_best_weights=True, verbose=1, monitor='val_accuracy', mode='max')
    
    print("  Starting model training...")
    model.fit(train_gen, epochs=EPOCHS, validation_data=(X_val, y_val),
              class_weight=class_weight, callbacks=[cb], verbose=1)

    model.save(EXPORT_DIR / "gesture_two_branch_mixup.h5")
    print("✔ Training done – artefacts saved in", EXPORT_DIR)

    from cmi_2025_metric_copy_for_import import CompetitionMetric
    preds_val = model.predict(X_val).argmax(1)
    true_val_int  = y_val.argmax(1)
    
    h_f1 = CompetitionMetric().calculate_hierarchical_f1(
        pd.DataFrame({'gesture': le.classes_[true_val_int]}),
        pd.DataFrame({'gesture': le.classes_[preds_val]}))
    print("Hold‑out H‑F1 =", round(h_f1, 4))

else:
    print("▶ INFERENCE MODE – loading artefacts from", PRETRAINED_DIR)
    final_feature_cols = np.load(PRETRAINED_DIR / "feature_cols.npy", allow_pickle=True).tolist()
    pad_len        = int(np.load(PRETRAINED_DIR / "sequence_maxlen.npy"))
    scaler         = joblib.load(PRETRAINED_DIR / "scaler.pkl")
    gesture_classes = np.load(PRETRAINED_DIR / "gesture_classes.npy", allow_pickle=True)

    temp_imu_cols = [c for c in final_feature_cols if c.startswith('acc_') or c.startswith('rot_')]
    imu_dim_final = len(temp_imu_cols)
    tof_thm_aggregated_dim_final = len(final_feature_cols) - imu_dim_final

    custom_objs = {
        'time_sum': time_sum,
        'squeeze_last_axis': squeeze_last_axis,
        'expand_last_axis': expand_last_axis,
        'se_block': se_block,
        'residual_se_cnn_block': residual_se_cnn_block,
        'attention_layer': attention_layer,
    }
    model = load_model(PRETRAINED_DIR / "gesture_two_branch_mixup.h5",
                       compile=False, custom_objects=custom_objs)
    print("  Model, scaler, feature_cols, pad_len loaded – ready for evaluation")
# Out:
# ▶ TRAIN MODE – loading dataset …
#   Calculating base engineered IMU features (magnitude, angle)...
#   Calculating engineered IMU derivatives (jerk, angular velocity) for original acc_mag...
#   Removing gravity and calculating linear acceleration features...
#   IMU (incl. engineered & derivatives) 13 | THM + Aggregated TOF 25 | total 38 features
#   Building sequences with aggregated TOF and preparing data for scaler...
#   Fitting StandardScaler...
#   Scaling and padding sequences...
#   Splitting data and preparing for training...
#   Starting model training...
# Epoch 1/160
# I0000 00:00:1750274133.923901      98 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1106 - loss: 9.7517
# 2025-06-18 19:15:40.604783: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 24s 56ms/step - accuracy: 0.1115 - loss: 9.7392 - val_accuracy: 0.2943 - val_loss: 7.9416
# Epoch 2/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.2687 - loss: 7.5008 - val_accuracy: 0.4316 - val_loss: 6.2990
# Epoch 3/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.3295 - loss: 6.2906 - val_accuracy: 0.4647 - val_loss: 5.2889
# Epoch 4/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.3897 - loss: 5.4361 - val_accuracy: 0.5187 - val_loss: 4.5972
# Epoch 5/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.4388 - loss: 4.8101 - val_accuracy: 0.5175 - val_loss: 4.1751
# Epoch 6/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.4577 - loss: 4.4083 - val_accuracy: 0.5402 - val_loss: 3.8298
# Epoch 7/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.4642 - loss: 4.1400 - val_accuracy: 0.5567 - val_loss: 3.5722
# Epoch 8/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.4791 - loss: 3.9074 - val_accuracy: 0.5708 - val_loss: 3.4042
# Epoch 9/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.4993 - loss: 3.6951 - val_accuracy: 0.5966 - val_loss: 3.2458
# Epoch 10/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.5396 - loss: 3.5750 - val_accuracy: 0.6162 - val_loss: 3.1318
# Epoch 11/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.5414 - loss: 3.5082 - val_accuracy: 0.6174 - val_loss: 3.0774
# Epoch 12/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.5515 - loss: 3.4146 - val_accuracy: 0.6291 - val_loss: 3.0197
# Epoch 13/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.5707 - loss: 3.3204 - val_accuracy: 0.6358 - val_loss: 2.9859
# Epoch 14/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.5692 - loss: 3.3317 - val_accuracy: 0.6327 - val_loss: 2.9754
# Epoch 15/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.5706 - loss: 3.2670 - val_accuracy: 0.5696 - val_loss: 3.0645
# Epoch 16/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.4941 - loss: 3.3849 - val_accuracy: 0.5420 - val_loss: 2.9135
# Epoch 17/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.5437 - loss: 3.1127 - val_accuracy: 0.5334 - val_loss: 2.8169
# Epoch 18/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.5241 - loss: 3.0099 - val_accuracy: 0.5794 - val_loss: 2.6013
# Epoch 19/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.5580 - loss: 2.8335 - val_accuracy: 0.5966 - val_loss: 2.4781
# Epoch 20/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.5728 - loss: 2.6681 - val_accuracy: 0.5941 - val_loss: 2.3845
# Epoch 21/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.5598 - loss: 2.6736 - val_accuracy: 0.6009 - val_loss: 2.2779
# Epoch 22/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.5826 - loss: 2.4710 - val_accuracy: 0.6217 - val_loss: 2.1463
# Epoch 23/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6186 - loss: 2.3295 - val_accuracy: 0.6033 - val_loss: 2.1265
# Epoch 24/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.6100 - loss: 2.3529 - val_accuracy: 0.6143 - val_loss: 2.0315
# Epoch 25/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6195 - loss: 2.2738 - val_accuracy: 0.6229 - val_loss: 1.9812
# Epoch 26/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6268 - loss: 2.1786 - val_accuracy: 0.6052 - val_loss: 1.9843
# Epoch 27/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6193 - loss: 2.2683 - val_accuracy: 0.6487 - val_loss: 1.8936
# Epoch 28/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6494 - loss: 2.1297 - val_accuracy: 0.6585 - val_loss: 1.8646
# Epoch 29/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6549 - loss: 2.0492 - val_accuracy: 0.6413 - val_loss: 1.8392
# Epoch 30/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6445 - loss: 2.0644 - val_accuracy: 0.6744 - val_loss: 1.7516
# Epoch 31/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6624 - loss: 2.0474 - val_accuracy: 0.6855 - val_loss: 1.7251
# Epoch 32/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.6569 - loss: 2.0630 - val_accuracy: 0.6652 - val_loss: 1.7761
# Epoch 33/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6687 - loss: 2.0423 - val_accuracy: 0.6898 - val_loss: 1.6871
# Epoch 34/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6843 - loss: 1.9412 - val_accuracy: 0.6732 - val_loss: 1.6987
# Epoch 35/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6888 - loss: 1.9366 - val_accuracy: 0.7057 - val_loss: 1.6390
# Epoch 36/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7257 - loss: 1.8288 - val_accuracy: 0.7057 - val_loss: 1.6219
# Epoch 37/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7315 - loss: 1.7658 - val_accuracy: 0.6990 - val_loss: 1.6224
# Epoch 38/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7207 - loss: 1.8211 - val_accuracy: 0.7088 - val_loss: 1.5977
# Epoch 39/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7483 - loss: 1.7435 - val_accuracy: 0.7186 - val_loss: 1.5668
# Epoch 40/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7367 - loss: 1.7534 - val_accuracy: 0.7149 - val_loss: 1.5691
# Epoch 41/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7416 - loss: 1.7376 - val_accuracy: 0.7204 - val_loss: 1.5548
# Epoch 42/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7463 - loss: 1.7738 - val_accuracy: 0.7216 - val_loss: 1.5615
# Epoch 43/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7241 - loss: 1.8635 - val_accuracy: 0.7241 - val_loss: 1.5549
# Epoch 44/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7234 - loss: 1.8491 - val_accuracy: 0.7265 - val_loss: 1.5542
# Epoch 45/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7317 - loss: 1.8462 - val_accuracy: 0.4813 - val_loss: 2.1766
# Epoch 46/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6137 - loss: 2.0928 - val_accuracy: 0.6284 - val_loss: 1.7673
# Epoch 47/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6084 - loss: 2.1186 - val_accuracy: 0.6487 - val_loss: 1.7582
# Epoch 48/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.6526 - loss: 2.0118 - val_accuracy: 0.6548 - val_loss: 1.7411
# Epoch 49/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6398 - loss: 2.0452 - val_accuracy: 0.6199 - val_loss: 1.8054
# Epoch 50/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6584 - loss: 1.9321 - val_accuracy: 0.6450 - val_loss: 1.7794
# Epoch 51/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6579 - loss: 1.9075 - val_accuracy: 0.6462 - val_loss: 1.7344
# Epoch 52/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6870 - loss: 1.8869 - val_accuracy: 0.6389 - val_loss: 1.7650
# Epoch 53/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6829 - loss: 1.9525 - val_accuracy: 0.6530 - val_loss: 1.7490
# Epoch 54/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6736 - loss: 1.8871 - val_accuracy: 0.6291 - val_loss: 1.7381
# Epoch 55/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6839 - loss: 1.8373 - val_accuracy: 0.6750 - val_loss: 1.6355
# Epoch 56/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6952 - loss: 1.8884 - val_accuracy: 0.6603 - val_loss: 1.6713
# Epoch 57/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6882 - loss: 1.8675 - val_accuracy: 0.6567 - val_loss: 1.6895
# Epoch 58/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6774 - loss: 1.9283 - val_accuracy: 0.6585 - val_loss: 1.6719
# Epoch 59/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6840 - loss: 1.8745 - val_accuracy: 0.6609 - val_loss: 1.6077
# Epoch 60/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6854 - loss: 1.8733 - val_accuracy: 0.6511 - val_loss: 1.7087
# Epoch 61/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6728 - loss: 1.8745 - val_accuracy: 0.6585 - val_loss: 1.6614
# Epoch 62/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6884 - loss: 1.8451 - val_accuracy: 0.6757 - val_loss: 1.5970
# Epoch 63/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7249 - loss: 1.8113 - val_accuracy: 0.6842 - val_loss: 1.5661
# Epoch 64/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7183 - loss: 1.8005 - val_accuracy: 0.6413 - val_loss: 1.6919
# Epoch 65/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7176 - loss: 1.8037 - val_accuracy: 0.6714 - val_loss: 1.6111
# Epoch 66/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7243 - loss: 1.7726 - val_accuracy: 0.6683 - val_loss: 1.6146
# Epoch 67/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7275 - loss: 1.7689 - val_accuracy: 0.6720 - val_loss: 1.5780
# Epoch 68/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7386 - loss: 1.7391 - val_accuracy: 0.6800 - val_loss: 1.5643
# Epoch 69/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7322 - loss: 1.7715 - val_accuracy: 0.6830 - val_loss: 1.5730
# Epoch 70/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7398 - loss: 1.6931 - val_accuracy: 0.7063 - val_loss: 1.5108
# Epoch 71/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7308 - loss: 1.6975 - val_accuracy: 0.6904 - val_loss: 1.5516
# Epoch 72/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7113 - loss: 1.8100 - val_accuracy: 0.6934 - val_loss: 1.5324
# Epoch 73/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7459 - loss: 1.7076 - val_accuracy: 0.7161 - val_loss: 1.5013
# Epoch 74/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7057 - loss: 1.8042 - val_accuracy: 0.7131 - val_loss: 1.4765
# Epoch 75/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7622 - loss: 1.6560 - val_accuracy: 0.7192 - val_loss: 1.4665
# Epoch 76/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7764 - loss: 1.5802 - val_accuracy: 0.7131 - val_loss: 1.4776
# Epoch 77/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7631 - loss: 1.6915 - val_accuracy: 0.7210 - val_loss: 1.4601
# Epoch 78/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7562 - loss: 1.6663 - val_accuracy: 0.7357 - val_loss: 1.4320
# Epoch 79/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7472 - loss: 1.6603 - val_accuracy: 0.7259 - val_loss: 1.4435
# Epoch 80/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7786 - loss: 1.6213 - val_accuracy: 0.7351 - val_loss: 1.4438
# Epoch 81/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7985 - loss: 1.5986 - val_accuracy: 0.7345 - val_loss: 1.4206
# Epoch 82/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8037 - loss: 1.5800 - val_accuracy: 0.7351 - val_loss: 1.4192
# Epoch 83/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7975 - loss: 1.5445 - val_accuracy: 0.7388 - val_loss: 1.4152
# Epoch 84/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7974 - loss: 1.5935 - val_accuracy: 0.7364 - val_loss: 1.4217
# Epoch 85/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7994 - loss: 1.5605 - val_accuracy: 0.7400 - val_loss: 1.4012
# Epoch 86/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8216 - loss: 1.4927 - val_accuracy: 0.7370 - val_loss: 1.3933
# Epoch 87/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7917 - loss: 1.5559 - val_accuracy: 0.7548 - val_loss: 1.3869
# Epoch 88/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8225 - loss: 1.5601 - val_accuracy: 0.7406 - val_loss: 1.3945
# Epoch 89/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8003 - loss: 1.5560 - val_accuracy: 0.7572 - val_loss: 1.3600
# Epoch 90/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8039 - loss: 1.5985 - val_accuracy: 0.7400 - val_loss: 1.4110
# Epoch 91/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8390 - loss: 1.4582 - val_accuracy: 0.7517 - val_loss: 1.3820
# Epoch 92/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8465 - loss: 1.4764 - val_accuracy: 0.7498 - val_loss: 1.3536
# Epoch 93/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8599 - loss: 1.4945 - val_accuracy: 0.7554 - val_loss: 1.3678
# Epoch 94/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7969 - loss: 1.5534 - val_accuracy: 0.7590 - val_loss: 1.3653
# Epoch 95/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8028 - loss: 1.5629 - val_accuracy: 0.7609 - val_loss: 1.3561
# Epoch 96/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8483 - loss: 1.4629 - val_accuracy: 0.7560 - val_loss: 1.3510
# Epoch 97/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8162 - loss: 1.5553 - val_accuracy: 0.7627 - val_loss: 1.3422
# Epoch 98/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8308 - loss: 1.5011 - val_accuracy: 0.7578 - val_loss: 1.3511
# Epoch 99/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8259 - loss: 1.5238 - val_accuracy: 0.7646 - val_loss: 1.3372
# Epoch 100/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8468 - loss: 1.4990 - val_accuracy: 0.7670 - val_loss: 1.3361
# Epoch 101/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8491 - loss: 1.4205 - val_accuracy: 0.7670 - val_loss: 1.3348
# Epoch 102/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8665 - loss: 1.4616 - val_accuracy: 0.7676 - val_loss: 1.3368
# Epoch 103/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8205 - loss: 1.6102 - val_accuracy: 0.7676 - val_loss: 1.3372
# Epoch 104/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8411 - loss: 1.4769 - val_accuracy: 0.7278 - val_loss: 1.3993
# Epoch 105/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7620 - loss: 1.6135 - val_accuracy: 0.5242 - val_loss: 1.9536
# Epoch 106/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7006 - loss: 1.8830 - val_accuracy: 0.6726 - val_loss: 1.5846
# Epoch 107/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6920 - loss: 1.8889 - val_accuracy: 0.6971 - val_loss: 1.5187
# Epoch 108/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6747 - loss: 1.8724 - val_accuracy: 0.6701 - val_loss: 1.6377
# Epoch 109/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7184 - loss: 1.7981 - val_accuracy: 0.6652 - val_loss: 1.6320
# Epoch 110/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7122 - loss: 1.7566 - val_accuracy: 0.6775 - val_loss: 1.6515
# Epoch 111/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6967 - loss: 1.8528 - val_accuracy: 0.6775 - val_loss: 1.6159
# Epoch 112/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7558 - loss: 1.6388 - val_accuracy: 0.6793 - val_loss: 1.6145
# Epoch 113/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7461 - loss: 1.6759 - val_accuracy: 0.6683 - val_loss: 1.6599
# Epoch 114/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7340 - loss: 1.7320 - val_accuracy: 0.6591 - val_loss: 1.6488
# Epoch 115/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7565 - loss: 1.6703 - val_accuracy: 0.6916 - val_loss: 1.6074
# Epoch 116/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7363 - loss: 1.7499 - val_accuracy: 0.6769 - val_loss: 1.6110
# Epoch 117/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7488 - loss: 1.7104 - val_accuracy: 0.7032 - val_loss: 1.5792
# Epoch 118/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7341 - loss: 1.7723 - val_accuracy: 0.6750 - val_loss: 1.6052
# Epoch 119/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7528 - loss: 1.6710 - val_accuracy: 0.6701 - val_loss: 1.6507
# Epoch 120/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7342 - loss: 1.7297 - val_accuracy: 0.7014 - val_loss: 1.5637
# Epoch 121/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7623 - loss: 1.7109 - val_accuracy: 0.7057 - val_loss: 1.5490
# Epoch 122/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7313 - loss: 1.7455 - val_accuracy: 0.7026 - val_loss: 1.5356
# Epoch 123/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7268 - loss: 1.7775 - val_accuracy: 0.6505 - val_loss: 1.6750
# Epoch 124/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7390 - loss: 1.7013 - val_accuracy: 0.7094 - val_loss: 1.5195
# Epoch 125/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7954 - loss: 1.6140 - val_accuracy: 0.6536 - val_loss: 1.6691
# Epoch 126/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7760 - loss: 1.5436 - val_accuracy: 0.6928 - val_loss: 1.5964
# Epoch 127/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7867 - loss: 1.5883 - val_accuracy: 0.7020 - val_loss: 1.5503
# Epoch 128/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7340 - loss: 1.7689 - val_accuracy: 0.6996 - val_loss: 1.5358
# Epoch 129/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7768 - loss: 1.6443 - val_accuracy: 0.6732 - val_loss: 1.6418
# Epoch 130/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7853 - loss: 1.5710 - val_accuracy: 0.6855 - val_loss: 1.6007
# Epoch 131/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7681 - loss: 1.7018 - val_accuracy: 0.6665 - val_loss: 1.6451
# Epoch 132/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7432 - loss: 1.7154 - val_accuracy: 0.6524 - val_loss: 1.6721
# Epoch 133/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7848 - loss: 1.6220 - val_accuracy: 0.6947 - val_loss: 1.5524
# Epoch 134/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7657 - loss: 1.6460 - val_accuracy: 0.7149 - val_loss: 1.5599
# Epoch 135/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7860 - loss: 1.5873 - val_accuracy: 0.7069 - val_loss: 1.5033
# Epoch 136/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7746 - loss: 1.7024 - val_accuracy: 0.7131 - val_loss: 1.5243
# Epoch 137/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8091 - loss: 1.5919 - val_accuracy: 0.6965 - val_loss: 1.5574
# Epoch 138/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7482 - loss: 1.7337 - val_accuracy: 0.7008 - val_loss: 1.5237
# Epoch 139/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7882 - loss: 1.6279 - val_accuracy: 0.7315 - val_loss: 1.4771
# Epoch 140/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7577 - loss: 1.7253 - val_accuracy: 0.7131 - val_loss: 1.5233
# Epoch 141/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7853 - loss: 1.6487 - val_accuracy: 0.7057 - val_loss: 1.5494
# Epoch 142/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7953 - loss: 1.6100 - val_accuracy: 0.7075 - val_loss: 1.5446
# Epoch 142: early stopping
# Restoring model weights from the end of the best epoch: 102.
# ✔ Training done – artefacts saved in .
# 2025-06-18 19:25:21.778577: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step
# Hold‑out H‑F1 = 0.8581

# %% [markdown]
# ### 》》》**Predict**

# %%
def predict(sequence: pl.DataFrame, demographics: pl.DataFrame) -> str:
    df_seq = sequence.to_pandas()

    df_seq['acc_mag'] = np.sqrt(df_seq['acc_x']**2 + df_seq['acc_y']**2 + df_seq['acc_z']**2)
    df_seq['rot_angle'] = 2 * np.arccos(df_seq['rot_w'].clip(-1, 1))
    df_seq['acc_mag_jerk'] = df_seq['acc_mag'].diff().fillna(0)
    df_seq['rot_angle_vel'] = df_seq['rot_angle'].diff().fillna(0)

    acc_cols_for_gravity_removal = ['acc_x', 'acc_y', 'acc_z']
    rot_cols_for_gravity_removal = ['rot_x', 'rot_y', 'rot_z', 'rot_w']

    if not all(col in df_seq.columns for col in acc_cols_for_gravity_removal + rot_cols_for_gravity_removal):
        print(f"Warning: Missing raw acc/rot columns for gravity removal in predict for sequence. Using raw acc as linear.")
        df_seq['linear_acc_x'] = df_seq.get('acc_x', 0)
        df_seq['linear_acc_y'] = df_seq.get('acc_y', 0)
        df_seq['linear_acc_z'] = df_seq.get('acc_z', 0)
    else:
        acc_data_seq = df_seq[acc_cols_for_gravity_removal]
        rot_data_seq = df_seq[rot_cols_for_gravity_removal]
        linear_accel_seq_arr = remove_gravity_from_acc(acc_data_seq, rot_data_seq)
        
        df_seq['linear_acc_x'] = linear_accel_seq_arr[:, 0]
        df_seq['linear_acc_y'] = linear_accel_seq_arr[:, 1]
        df_seq['linear_acc_z'] = linear_accel_seq_arr[:, 2]
    
    df_seq['linear_acc_mag'] = np.sqrt(df_seq['linear_acc_x']**2 + df_seq['linear_acc_y']**2 + df_seq['linear_acc_z']**2)
    df_seq['linear_acc_mag_jerk'] = df_seq['linear_acc_mag'].diff().fillna(0)
    
    for i in range(1, 6): 
        pixel_cols_tof = [f"tof_{i}_v{p}" for p in range(64)]
        if not all(col in df_seq.columns for col in pixel_cols_tof):
            print(f"Warning: Missing some TOF pixel columns for tof_{i} in predict. Filling aggregates with 0.")
            df_seq[f'tof_{i}_mean'] = 0
            df_seq[f'tof_{i}_std']  = 0
            df_seq[f'tof_{i}_min']  = 0
            df_seq[f'tof_{i}_max']  = 0
            continue

        tof_sensor_data = df_seq[pixel_cols_tof].replace(-1, np.nan)
        df_seq[f'tof_{i}_mean'] = tof_sensor_data.mean(axis=1)
        df_seq[f'tof_{i}_std']  = tof_sensor_data.std(axis=1)
        df_seq[f'tof_{i}_min']  = tof_sensor_data.min(axis=1)
        df_seq[f'tof_{i}_max']  = tof_sensor_data.max(axis=1)
        
    if 'tof_range_across_sensors' in final_feature_cols:
        tof_mean_cols_for_contrast = [f'tof_{i}_mean' for i in range(1, 6) if f'tof_{i}_mean' in df_seq.columns]
        thm_cols_for_contrast = [f'thm_{i}' for i in range(1, 6) if f'thm_{i}' in df_seq.columns]

        if tof_mean_cols_for_contrast:
            tof_values_for_contrast = df_seq[tof_mean_cols_for_contrast]
            df_seq['tof_range_across_sensors'] = tof_values_for_contrast.max(axis=1) - tof_values_for_contrast.min(axis=1)
            df_seq['tof_std_across_sensors'] = tof_values_for_contrast.std(axis=1)
        else:
            df_seq['tof_range_across_sensors'] = 0
            df_seq['tof_std_across_sensors'] = 0

        if thm_cols_for_contrast:
            thm_values_for_contrast = df_seq[thm_cols_for_contrast]
            df_seq['thm_range_across_sensors'] = thm_values_for_contrast.max(axis=1) - thm_values_for_contrast.min(axis=1)
            df_seq['thm_std_across_sensors'] = thm_values_for_contrast.std(axis=1)
        else:
            df_seq['thm_range_across_sensors'] = 0
            df_seq['thm_std_across_sensors'] = 0
        
    df_seq_final_features = pd.DataFrame(index=df_seq.index)
    for col_name in final_feature_cols:
        if col_name in df_seq.columns:
            df_seq_final_features[col_name] = df_seq[col_name]
        else:
            print(f"CRITICAL ERROR IN PREDICT: Feature '{col_name}' expected by model (from final_feature_cols) was NOT generated in df_seq. Filling with 0. THIS IS LIKELY A BUG.")
            df_seq_final_features[col_name] = 0 
            
    mat_unscaled = df_seq_final_features.ffill().bfill().fillna(0).values.astype('float32')
    
    mat_scaled = scaler.transform(mat_unscaled)
    
    pad_input = pad_sequences([mat_scaled], maxlen=pad_len, padding='post', truncating='post', dtype='float32')
    
    idx = int(model.predict(pad_input, verbose=0).argmax(1)[0])
    return str(gesture_classes[idx])

# %% [markdown]
# ### 》》》**Submit Inference server**

# %%
import kaggle_evaluation.cmi_inference_server
inference_server = kaggle_evaluation.cmi_inference_server.CMIInferenceServer(predict)

if os.getenv('KAGGLE_IS_COMPETITION_RERUN'):
    inference_server.serve()
else:
    inference_server.run_local_gateway(
        data_paths=(
            '/kaggle/input/cmi-detect-behavior-with-sensor-data/test.csv',
            '/kaggle/input/cmi-detect-behavior-with-sensor-data/test_demographics.csv',
        )
    )
