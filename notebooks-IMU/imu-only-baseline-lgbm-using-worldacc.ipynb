# %%
# CMI BFRB Detection - LightGBM with World Acceleration Feature
# A simple LightGBM implementation for BFRB classification with world coordinate transformation
# 
# Key Innovation: Converting device acceleration to world coordinates using quaternion rotations
# This helps normalize hand orientation differences across subjects and positions
# Thanks https://www.kaggle.com/competitions/cmi-detect-behavior-with-sensor-data/discussion/583080 @tatamikenn for your idea!

import os
import numpy as np
import pandas as pd
import polars as pl
import joblib
from typing import Tuple, List, Optional
import warnings
warnings.filterwarnings('ignore')

# ML utilities
from sklearn.model_selection import StratifiedGroupKFold, PredefinedSplit
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import f1_score, accuracy_score
from lightgbm import LGBMClassifier, log_evaluation, early_stopping

# World coordinate transformation
from scipy.spatial.transform import Rotation as R

# Competition specific
import kaggle_evaluation.cmi_inference_server

print("✓ All imports loaded successfully")

# =============================================================================
# CONFIGURATION
# =============================================================================

class Config: 
    """Central configuration class for training and data parameters"""
    
    # Paths for Kaggle environment
    TRAIN_PATH = "/kaggle/input/cmi-detect-behavior-with-sensor-data/train.csv"
    TRAIN_DEMOGRAPHICS_PATH = "/kaggle/input/cmi-detect-behavior-with-sensor-data/train_demographics.csv"
    TEST_PATH = "/kaggle/input/cmi-detect-behavior-with-sensor-data/test.csv"
    TEST_DEMOGRAPHICS_PATH = "/kaggle/input/cmi-detect-behavior-with-sensor-data/test_demographics.csv"
    
    # Training parameters
    SEED = 42
    N_FOLDS = 5
    
    # Feature columns
    ACC_COLS = ['acc_x', 'acc_y', 'acc_z']
    ROT_COLS = ['rot_w', 'rot_x', 'rot_y', 'rot_z']
    
    # LightGBM parameters
    LGBM_PARAMS = {
        'objective': 'multiclass',
        'n_estimators': 1024,
        'max_depth': 8,
        'learning_rate': 0.025,
        'colsample_bytree': 0.5,
        'n_jobs': -1,
        'num_leaves': 20,
        'random_state': 42,
        'reg_alpha': 0.1,
        'reg_lambda': 0.1,
        'subsample': 0.5,
        'verbosity': -1,
        # 'device': 'gpu',  # Will be set automatically based on availability
    }

# Set reproducibility
np.random.seed(Config.SEED)

def check_gpu_availability():
    """Check if GPU is available for LightGBM"""
    try:
        # Try to create a simple LightGBM model with GPU
        from lightgbm import LGBMClassifier
        import numpy as np
        
        # Create dummy data
        X_dummy = np.random.rand(100, 10)
        y_dummy = np.random.randint(0, 2, 100)
        
        # Try GPU
        model = LGBMClassifier(n_estimators=1, device='gpu', verbosity=-1)
        model.fit(X_dummy, y_dummy)
        print("✓ GPU available for LightGBM")
        return 'gpu'
    except:
        print("⚠️  GPU not available, using CPU for LightGBM")
        return 'cpu'

# Check GPU availability
DEVICE = check_gpu_availability()

print(f"✓ Configuration loaded for Kaggle environment (Device: {DEVICE})")

# =============================================================================
# GESTURE MAPPING
# =============================================================================

# Gesture mapping (targets 0-7 are BFRB, 8-17 are non-BFRB)
GESTURE_MAPPER = {
    "Above ear - pull hair": 0,
    "Cheek - pinch skin": 1,
    "Eyebrow - pull hair": 2,
    "Eyelash - pull hair": 3, 
    "Forehead - pull hairline": 4,
    "Forehead - scratch": 5,
    "Neck - pinch skin": 6, 
    "Neck - scratch": 7,
    
    "Drink from bottle/cup": 8,
    "Feel around in tray and pull out an object": 9,
    "Glasses on/off": 10,
    "Pinch knee/leg skin": 11, 
    "Pull air toward your face": 12,
    "Scratch knee/leg skin": 13,
    "Text on phone": 14,
    "Wave hello": 15,
    "Write name in air": 16,
    "Write name on leg": 17,
}

REVERSE_GESTURE_MAPPER = {v: k for k, v in GESTURE_MAPPER.items()}

# =============================================================================
# COMPETITION METRIC
# =============================================================================

def competition_metric(y_true, y_pred) -> tuple:
    """Calculate the competition metric (Binary F1 + Macro F1) / 2"""
    
    # Binary F1: BFRB vs non-BFRB
    binary_f1 = f1_score(
        np.where(y_true <= 7, 1, 0),
        np.where(y_pred <= 7, 1, 0),
        zero_division=0.0,
    )
    
    # Macro F1: specific gesture classification (only for BFRB gestures)
    macro_f1 = f1_score(
        np.where(y_true <= 7, y_true, 99),  # Map non-BFRB to 99
        np.where(y_pred <= 7, y_pred, 99),  # Map non-BFRB to 99
        average="macro", 
        zero_division=0.0,
    )
    
    # Final competition score
    final_score = 0.5 * (binary_f1 + macro_f1)
    
    return final_score, binary_f1, macro_f1

# =============================================================================
# CORE FEATURE ENGINEERING: WORLD ACCELERATION
# =============================================================================

def handle_quaternion_missing_values(rot_data: np.ndarray) -> np.ndarray:
    """
    Handle missing values in quaternion data intelligently
    
    Key insight: Quaternions must have unit length |q| = 1
    If one component is missing, we can reconstruct it from the others
    """
    rot_cleaned = rot_data.copy()
    
    for i in range(len(rot_data)):
        row = rot_data[i]
        missing_count = np.isnan(row).sum()
        
        if missing_count == 0:
            # No missing values, normalize to unit quaternion
            norm = np.linalg.norm(row)
            if norm > 1e-8:
                rot_cleaned[i] = row / norm
            else:
                rot_cleaned[i] = [1.0, 0.0, 0.0, 0.0]  # Identity quaternion
                
        elif missing_count == 1:
            # One missing value, reconstruct using unit quaternion constraint
            # |w|² + |x|² + |y|² + |z|² = 1
            missing_idx = np.where(np.isnan(row))[0][0]
            valid_values = row[~np.isnan(row)]
            
            sum_squares = np.sum(valid_values**2)
            if sum_squares <= 1.0:
                missing_value = np.sqrt(max(0, 1.0 - sum_squares))
                # Choose sign for continuity with previous quaternion
                if i > 0 and not np.isnan(rot_cleaned[i-1, missing_idx]):
                    if rot_cleaned[i-1, missing_idx] < 0:
                        missing_value = -missing_value
                rot_cleaned[i, missing_idx] = missing_value
                rot_cleaned[i, ~np.isnan(row)] = valid_values
            else:
                rot_cleaned[i] = [1.0, 0.0, 0.0, 0.0]
        else:
            # More than one missing value, use identity quaternion
            rot_cleaned[i] = [1.0, 0.0, 0.0, 0.0]
    
    return rot_cleaned

def compute_world_acceleration(acc: np.ndarray, rot: np.ndarray) -> np.ndarray:
    """
    Convert acceleration from device coordinates to world coordinates
    
    This is the key innovation: normalizing for device orientation
    
    Args:
        acc: acceleration in device coordinates, shape (time_steps, 3) [x, y, z]
        rot: rotation quaternion, shape (time_steps, 4) [w, x, y, z] (normalized)
    
    Returns:
        acc_world: acceleration in world coordinates, shape (time_steps, 3)
        
    Why this matters:
    - Device acceleration depends on how the watch is oriented on the wrist
    - World acceleration is independent of device orientation
    - This helps the model focus on actual hand motion rather than wrist rotation
    """
    try:
        # Convert quaternion format from [w, x, y, z] to [x, y, z, w] for scipy
        rot_scipy = rot[:, [1, 2, 3, 0]]
        
        # Verify quaternions are valid (non-zero norm)
        norms = np.linalg.norm(rot_scipy, axis=1)
        if np.any(norms < 1e-8):
            # Replace problematic quaternions with identity
            mask = norms < 1e-8
            rot_scipy[mask] = [0.0, 0.0, 0.0, 1.0]  # Identity quaternion in scipy format
        
        # Create rotation object and apply transformation
        r = R.from_quat(rot_scipy)
        acc_world = r.apply(acc)
        
    except Exception:
        # Fallback to original acceleration if transformation fails
        print("Warning: World coordinate transformation failed, using device coordinates")
        acc_world = acc.copy()
    
    return acc_world

# =============================================================================
# SIMPLIFIED FEATURE EXTRACTION
# =============================================================================

def extract_comprehensive_features(sequence: pl.DataFrame, demographics: pl.DataFrame) -> pd.DataFrame:
    """
    Extract features from IMU data with world acceleration transformation
    
    Feature Groups:
    1. Device Acceleration (acc_x, acc_y, acc_z) - raw sensor data
    2. Rotation Quaternion (rot_w, rot_x, rot_y, rot_z) - device orientation  
    3. World Acceleration (NEW) - orientation-normalized acceleration
    4. Demographics - subject characteristics
    5. Sequence metadata - length, etc.
    """
    
    # Convert to pandas for processing
    seq_df = sequence.to_pandas()
    demo_df = demographics.to_pandas()
    
    # Handle missing values in basic sensor data
    acc_data = seq_df[Config.ACC_COLS].copy()
    acc_data = acc_data.ffill().bfill().fillna(0)
    
    rot_data = seq_df[Config.ROT_COLS].copy()
    rot_data = rot_data.ffill().bfill()
    
    # Handle quaternion missing values and normalize
    rot_data_clean = handle_quaternion_missing_values(rot_data.values)
    
    # CORE INNOVATION: Compute world acceleration
    try:
        world_acc_data = compute_world_acceleration(acc_data.values, rot_data_clean)
        # print("✓ World acceleration computed successfully")  # Reduced verbosity
    except Exception as e:
        print(f"Warning: World acceleration computation failed: {e}")
        world_acc_data = acc_data.values.copy()  # Fallback to device coordinates
    
    # Initialize feature dictionary
    features = {}
    
    # Add sequence metadata
    features['sequence_length'] = len(seq_df)
    
    # Add demographics features
    if len(demo_df) > 0:
        demo_row = demo_df.iloc[0]
        features['age'] = demo_row.get('age', 0)
        features['adult_child'] = demo_row.get('adult_child', 0)
        features['sex'] = demo_row.get('sex', 0)
        features['handedness'] = demo_row.get('handedness', 0)
        features['height_cm'] = demo_row.get('height_cm', 0)
        features['shoulder_to_wrist_cm'] = demo_row.get('shoulder_to_wrist_cm', 0)
        features['elbow_to_wrist_cm'] = demo_row.get('elbow_to_wrist_cm', 0)
    
    # Define feature arrays for statistical extraction
    feature_arrays = {
        'acc': acc_data.values,           # Device acceleration (3D)
        'rot': rot_data_clean,            # Rotation quaternion (4D) 
        'world_acc': world_acc_data,      # World acceleration (3D) - KEY INNOVATION
    }
    
    # Extract statistical features for each data source
    for source_name, array in feature_arrays.items():
        if array.ndim == 1:
            array = array.reshape(-1, 1)
        
        n_features = array.shape[1]
        
        for feat_idx in range(n_features):
            feat_data = array[:, feat_idx]
            
            # Create feature name
            if source_name == 'acc':
                axis_names = ['x', 'y', 'z']
                prefix = f"acc_{axis_names[feat_idx]}"
            elif source_name == 'rot':
                comp_names = ['w', 'x', 'y', 'z']
                prefix = f"rot_{comp_names[feat_idx]}"
            elif source_name == 'world_acc':
                axis_names = ['x', 'y', 'z']  
                prefix = f"world_acc_{axis_names[feat_idx]}"
            else:
                prefix = f"{source_name}_{feat_idx}" if n_features > 1 else source_name
            
            # Extract comprehensive statistical features
            features.update(extract_statistical_features(feat_data, prefix))
    
    # Compute magnitude features (important for motion intensity)
    acc_magnitude = np.linalg.norm(acc_data.values, axis=1)
    world_acc_magnitude = np.linalg.norm(world_acc_data, axis=1)
    
    features.update(extract_statistical_features(acc_magnitude, 'acc_magnitude'))
    features.update(extract_statistical_features(world_acc_magnitude, 'world_acc_magnitude'))
    
    # Cross-feature: difference between device and world acceleration magnitudes
    # This captures how much device orientation affects motion measurement
    acc_world_diff = acc_magnitude - world_acc_magnitude
    features.update(extract_statistical_features(acc_world_diff, 'acc_world_diff'))
    
    # Convert to DataFrame
    result_df = pd.DataFrame([features])
    
    # Handle any remaining NaN values
    result_df = result_df.fillna(0)
    
    return result_df

def extract_statistical_features(data: np.ndarray, prefix: str) -> dict:
    """
    Extract comprehensive statistical features from a 1D time series
    
    Returns features that capture:
    - Central tendency: mean, median, mode region
    - Spread: std, variance, range, IQR  
    - Shape: skewness, kurtosis
    - Dynamics: differences, trends, changes
    - Segments: beginning vs middle vs end behavior
    """
    
    features = {}
    
    # Basic statistics
    features[f'{prefix}_mean'] = np.mean(data)
    features[f'{prefix}_std'] = np.std(data)
    features[f'{prefix}_var'] = np.var(data)
    features[f'{prefix}_min'] = np.min(data)
    features[f'{prefix}_max'] = np.max(data)
    features[f'{prefix}_median'] = np.median(data)
    features[f'{prefix}_q25'] = np.percentile(data, 25)
    features[f'{prefix}_q75'] = np.percentile(data, 75)
    features[f'{prefix}_iqr'] = np.percentile(data, 75) - np.percentile(data, 25)
    
    # Range and boundary features
    features[f'{prefix}_range'] = np.max(data) - np.min(data)
    features[f'{prefix}_first'] = data[0] if len(data) > 0 else 0
    features[f'{prefix}_last'] = data[-1] if len(data) > 0 else 0
    features[f'{prefix}_delta'] = data[-1] - data[0] if len(data) > 0 else 0
    
    # Higher order moments (shape of distribution)
    if len(data) > 1 and np.std(data) > 1e-8:
        features[f'{prefix}_skew'] = pd.Series(data).skew()
        features[f'{prefix}_kurt'] = pd.Series(data).kurtosis()
    else:
        features[f'{prefix}_skew'] = 0
        features[f'{prefix}_kurt'] = 0
    
    # Differential features (capture dynamics)
    if len(data) > 1:
        diff_data = np.diff(data)
        features[f'{prefix}_diff_mean'] = np.mean(diff_data)
        features[f'{prefix}_diff_std'] = np.std(diff_data)
        features[f'{prefix}_n_changes'] = np.sum(np.abs(diff_data) > np.std(data) * 0.1)  # Significant changes
    else:
        features[f'{prefix}_diff_mean'] = 0
        features[f'{prefix}_diff_std'] = 0
        features[f'{prefix}_n_changes'] = 0
    
    # Correlation with time (trend detection)
    if len(data) > 2:
        time_indices = np.arange(len(data))
        try:
            corr_coef = np.corrcoef(time_indices, data)[0, 1]
            features[f'{prefix}_time_corr'] = corr_coef if not np.isnan(corr_coef) else 0
        except:
            features[f'{prefix}_time_corr'] = 0
    else:
        features[f'{prefix}_time_corr'] = 0
    
    # Segment features (beginning, middle, end patterns)
    seq_len = len(data)
    if seq_len >= 9:  # Need sufficient data for meaningful segments
        seg_size = seq_len // 3
        seg1 = data[:seg_size]           # Beginning (Transition phase)
        seg2 = data[seg_size:2*seg_size] # Middle (Pause phase)  
        seg3 = data[2*seg_size:]         # End (Gesture phase)
        
        features[f'{prefix}_seg1_mean'] = np.mean(seg1)
        features[f'{prefix}_seg2_mean'] = np.mean(seg2)
        features[f'{prefix}_seg3_mean'] = np.mean(seg3)
        
        features[f'{prefix}_seg1_std'] = np.std(seg1)
        features[f'{prefix}_seg2_std'] = np.std(seg2)
        features[f'{prefix}_seg3_std'] = np.std(seg3)
        
        # Segment transitions (important for distinguishing gesture types)
        features[f'{prefix}_seg1_to_seg2'] = np.mean(seg2) - np.mean(seg1)
        features[f'{prefix}_seg2_to_seg3'] = np.mean(seg3) - np.mean(seg2)
    else:
        # Not enough data for meaningful segments
        for seg in [1, 2, 3]:
            features[f'{prefix}_seg{seg}_mean'] = features[f'{prefix}_mean']
            features[f'{prefix}_seg{seg}_std'] = features[f'{prefix}_std']
        features[f'{prefix}_seg1_to_seg2'] = 0
        features[f'{prefix}_seg2_to_seg3'] = 0
    
    return features

# =============================================================================
# DATA LOADING AND PREPROCESSING
# =============================================================================

def load_and_prepare_data():
    """Load and prepare training data with comprehensive features"""
    
    print("Loading training data...")
    train_df = pl.read_csv(Config.TRAIN_PATH)
    train_demographics = pl.read_csv(Config.TRAIN_DEMOGRAPHICS_PATH)
    
    print("Loading test data...")
    test_df = pl.read_csv(Config.TEST_PATH)
    test_demographics = pl.read_csv(Config.TEST_DEMOGRAPHICS_PATH)
    
    # Get common columns between train and test (exclude thermal and ToF sensors)
    train_cols = set(train_df.columns)
    test_cols = set(test_df.columns)
    common_cols = train_cols.intersection(test_cols)
    
    # Filter to IMU-only columns (remove thermal and ToF sensors)
    imu_cols = [col for col in common_cols if not (col.startswith('thm_') or col.startswith('tof_'))]
    
    print(f"✓ Using {len(imu_cols)} common IMU columns")
    print(f"✓ Train-only columns: {train_cols - test_cols}")
    print(f"✓ Test-only columns: {test_cols - train_cols}")
    
    print("Extracting features for training sequences...")
    train_features_list = []
    train_labels = []
    train_subjects = []
    train_sequence_ids = []
    
    # Group by sequence_id for training data - need to include gesture column for labels
    train_imu_cols = imu_cols + ['gesture'] if 'gesture' not in imu_cols else imu_cols
    train_sequences = train_df.select(pl.col(train_imu_cols)).group_by('sequence_id', maintain_order=True)
    
    for sequence_id, sequence_data in train_sequences:
        # Get sequence features
        sequence_id_val = sequence_id[0] if isinstance(sequence_id, tuple) else sequence_id
        
        # Get demographics for this sequence
        subject_id = sequence_data['subject'][0]
        subject_demographics = train_demographics.filter(pl.col('subject') == subject_id)
        
        # Extract features (only IMU columns for feature extraction)
        imu_only_data = sequence_data.select(pl.col(imu_cols))
        features = extract_comprehensive_features(imu_only_data, subject_demographics)
        features['sequence_id'] = sequence_id_val
        
        train_features_list.append(features)
        
        # Get label (gesture) for this sequence
        gesture = sequence_data['gesture'][0]
        label = GESTURE_MAPPER[gesture]
        train_labels.append(label)
        train_subjects.append(subject_id)
        train_sequence_ids.append(sequence_id_val)
    
    # Combine all training features
    X_train = pd.concat(train_features_list, ignore_index=True)
    y_train = np.array(train_labels)
    subjects = np.array(train_subjects)
    
    print("Extracting features for test sequences...")
    test_features_list = []
    test_sequence_ids = []
    
    # Group by sequence_id for test data  
    test_sequences = test_df.select(pl.col(imu_cols)).group_by('sequence_id', maintain_order=True)
    
    for sequence_id, sequence_data in test_sequences:
        sequence_id_val = sequence_id[0] if isinstance(sequence_id, tuple) else sequence_id
        
        # Get demographics for this sequence
        subject_id = sequence_data['subject'][0]
        subject_demographics = test_demographics.filter(pl.col('subject') == subject_id)
        
        # Extract features using the same function as training
        features = extract_comprehensive_features(sequence_data, subject_demographics)
        features['sequence_id'] = sequence_id_val
        
        test_features_list.append(features)
        test_sequence_ids.append(sequence_id_val)
    
    # Combine all test features
    X_test = pd.concat(test_features_list, ignore_index=True)
    
    print(f"✓ Training features shape: {X_train.shape}")
    print(f"✓ Training labels shape: {y_train.shape}")
    print(f"✓ Test features shape: {X_test.shape}")
    print(f"✓ Number of features: {X_train.shape[1] - 1}")  # -1 for sequence_id
    
    return X_train, y_train, subjects, X_test, test_sequence_ids, imu_cols

# =============================================================================
# MODEL TRAINING WITH CROSS-VALIDATION
# =============================================================================

def train_lightgbm_models(X_train, y_train, subjects):
    """Train LightGBM models using stratified group k-fold cross-validation"""
    
    print(f"Training LightGBM models with {Config.N_FOLDS}-fold cross-validation...")
    
    # Prepare features (remove sequence_id)
    feature_cols = [col for col in X_train.columns if col != 'sequence_id']
    X_features = X_train[feature_cols]
    
    # Setup cross-validation
    cv = StratifiedGroupKFold(n_splits=Config.N_FOLDS, shuffle=True, random_state=Config.SEED)
    
    models = []
    oof_predictions = np.zeros(len(y_train))
    cv_scores = []
    
    print(f"Feature columns: {len(feature_cols)}")
    print("Starting cross-validation...")
    
    for fold, (train_idx, val_idx) in enumerate(cv.split(X_features, y_train, subjects)):
        print(f"\n--- Fold {fold + 1}/{Config.N_FOLDS} ---")
        
        # Split data
        X_fold_train = X_features.iloc[train_idx]
        X_fold_val = X_features.iloc[val_idx]
        y_fold_train = y_train[train_idx]
        y_fold_val = y_train[val_idx]
        
        print(f"Train size: {len(X_fold_train)}, Val size: {len(X_fold_val)}")
        
        # Train model with monitoring and device detection
        lgbm_params = Config.LGBM_PARAMS.copy()
        lgbm_params['device'] = DEVICE  # Use detected device
        
        model = LGBMClassifier(**lgbm_params)
        
        print(f"Training fold {fold + 1} with monitoring every 5 rounds (Device: {DEVICE})...")
        model.fit(
            X_fold_train, y_fold_train,
            eval_set=[(X_fold_train, y_fold_train), (X_fold_val, y_fold_val)],
            eval_names=['train', 'valid'],
            eval_metric=['multi_logloss', 'multi_error'],
            callbacks=[
                log_evaluation(period=5),  # Output every 5 rounds
                early_stopping(stopping_rounds=100, verbose=True)
            ]
        )
        
        # Predictions
        val_preds = model.predict(X_fold_val)
        oof_predictions[val_idx] = val_preds
        
        # Calculate metrics
        score, binary_f1, macro_f1 = competition_metric(y_fold_val, val_preds)
        cv_scores.append(score)
        
        print(f"Fold {fold + 1} - Competition Score: {score:.4f} (Binary F1: {binary_f1:.4f}, Macro F1: {macro_f1:.4f})")
        
        models.append(model)
    
    # Overall CV performance
    overall_score, overall_binary_f1, overall_macro_f1 = competition_metric(y_train, oof_predictions)
    
    print(f"\n{'='*60}")
    print("CROSS-VALIDATION RESULTS")
    print(f"{'='*60}")
    print(f"Overall Competition Score: {overall_score:.4f} ± {np.std(cv_scores):.4f}")
    print(f"Overall Binary F1: {overall_binary_f1:.4f}")
    print(f"Overall Macro F1: {overall_macro_f1:.4f}")
    print(f"Fold scores: {[f'{score:.4f}' for score in cv_scores]}")
    print(f"{'='*60}")
    
    return models, cv_scores, overall_score

# =============================================================================
# INFERENCE FUNCTION
# =============================================================================

def create_prediction_function(models, feature_cols, imu_cols):
    """Create prediction function for Kaggle evaluation"""
    
    def predict(sequence: pl.DataFrame, demographics: pl.DataFrame) -> str:
        """
        Prediction function for Kaggle evaluation
        Uses ensemble of trained LightGBM models
        """
        try:
            # Filter sequence to only include IMU columns that we trained with
            available_cols = sequence.columns
            sequence_imu_cols = [col for col in imu_cols if col in available_cols]
            sequence_filtered = sequence.select(pl.col(sequence_imu_cols))
            
            # Extract features using the same method as training
            features = extract_comprehensive_features(sequence_filtered, demographics)
            
            # Ensure we have the same features as training
            missing_features = [col for col in feature_cols if col not in features.columns]
            if missing_features:
                print(f"Warning: Missing features {missing_features}, filling with zeros")
                for col in missing_features:
                    features[col] = 0
            
            X_pred = features[feature_cols]
            
            # Get predictions from all models
            predictions = []
            for model in models:
                pred_probs = model.predict_proba(X_pred)
                pred_class = np.argmax(pred_probs, axis=1)[0]
                predictions.append(pred_class)
            
            # Ensemble prediction (majority vote)
            final_prediction = max(set(predictions), key=predictions.count)
            
            # Convert back to gesture name
            gesture_name = REVERSE_GESTURE_MAPPER[final_prediction]
            
            print(f"Predicted: {gesture_name} (class {final_prediction})")
            return gesture_name
            
        except Exception as e:
            print(f"Prediction error: {e}")
            import traceback
            traceback.print_exc()
            return 'Text on phone'  # Fallback prediction
    
    return predict

# =============================================================================
# MAIN EXECUTION
# =============================================================================

def main():
    """Main execution pipeline"""
    
    print("="*60)
    print("CMI BFRB Detection - LightGBM with World Acceleration Feature")
    print("="*60)
    print("🚀 Key Innovation: World Coordinate Transformation")
    print("   Converting device acceleration to world coordinates")
    print("   This normalizes for different wrist orientations!")
    print("="*60)
    
    # Load and prepare data
    X_train, y_train, subjects, X_test, test_sequence_ids, imu_cols = load_and_prepare_data()
    
    # Train models
    models, cv_scores, overall_score = train_lightgbm_models(X_train, y_train, subjects)
    
    # Prepare feature columns for inference
    feature_cols = [col for col in X_train.columns if col != 'sequence_id']
    
    # Create prediction function
    predict_func = create_prediction_function(models, feature_cols, imu_cols)
    
    print(f"\n✓ Training completed successfully!")
    print(f"✓ Final CV Score: {overall_score:.4f}")
    print(f"✓ Core innovation: World acceleration transformation")
    print(f"✓ Models ready for inference")
    
    return predict_func, models, cv_scores

# Execute main pipeline
if __name__ == "__main__":
    predict_function, trained_models, cv_scores = main()
    
    # Setup inference server
    print("\nSetting up inference server...")
    inference_server = kaggle_evaluation.cmi_inference_server.CMIInferenceServer(predict_function)
    
    if os.getenv('KAGGLE_IS_COMPETITION_RERUN'):
        inference_server.serve()
    else:
        # Local testing
        inference_server.run_local_gateway(
            data_paths=(
                Config.TEST_PATH,
                Config.TEST_DEMOGRAPHICS_PATH,
            )
        )
# Out:
# ✓ All imports loaded successfully
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# ✓ GPU available for LightGBM
# ✓ Configuration loaded for Kaggle environment (Device: gpu)
# ============================================================
# CMI BFRB Detection - LightGBM with World Acceleration Feature
# ============================================================
# 🚀 Key Innovation: World Coordinate Transformation
#    Converting device acceleration to world coordinates
#    This normalizes for different wrist orientations!
# ============================================================
# Loading training data...
# Loading test data...
# ✓ Using 11 common IMU columns
# ✓ Train-only columns: {'sequence_type', 'gesture', 'phase', 'orientation', 'behavior'}
# ✓ Test-only columns: set()
# Extracting features for training sequences...
# Extracting features for test sequences...
# ✓ Training features shape: (8151, 360)
# ✓ Training labels shape: (8151,)
# ✓ Test features shape: (2, 360)
# ✓ Number of features: 359
# Training LightGBM models with 5-fold cross-validation...
# Feature columns: 359
# Starting cross-validation...
#
# --- Fold 1/5 ---
# Train size: 6623, Val size: 1528
# Training fold 1 with monitoring every 5 rounds (Device: gpu)...
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# Training until validation scores don't improve for 100 rounds
# [5]	train's multi_logloss: 2.27826	train's multi_error: 0.369772	valid's multi_logloss: 2.35797	valid's multi_error: 0.510471
# [10]	train's multi_logloss: 2.00405	train's multi_error: 0.289748	valid's multi_logloss: 2.15056	valid's multi_error: 0.479058
# [15]	train's multi_logloss: 1.80132	train's multi_error: 0.25336	valid's multi_logloss: 1.99924	valid's multi_error: 0.456152
# [20]	train's multi_logloss: 1.63725	train's multi_error: 0.224219	valid's multi_logloss: 1.87504	valid's multi_error: 0.443063
# [25]	train's multi_logloss: 1.50388	train's multi_error: 0.199456	valid's multi_logloss: 1.77969	valid's multi_error: 0.437173
# [30]	train's multi_logloss: 1.39067	train's multi_error: 0.181942	valid's multi_logloss: 1.70092	valid's multi_error: 0.437827
# [35]	train's multi_logloss: 1.29264	train's multi_error: 0.167749	valid's multi_logloss: 1.6357	valid's multi_error: 0.426702
# [40]	train's multi_logloss: 1.20814	train's multi_error: 0.15567	valid's multi_logloss: 1.57881	valid's multi_error: 0.422775
# [45]	train's multi_logloss: 1.13283	train's multi_error: 0.141477	valid's multi_logloss: 1.52842	valid's multi_error: 0.417539
# [50]	train's multi_logloss: 1.06616	train's multi_error: 0.130907	valid's multi_logloss: 1.48688	valid's multi_error: 0.412958
# [55]	train's multi_logloss: 1.00588	train's multi_error: 0.121697	valid's multi_logloss: 1.44979	valid's multi_error: 0.415576
# [60]	train's multi_logloss: 0.951067	train's multi_error: 0.110524	valid's multi_logloss: 1.41564	valid's multi_error: 0.412958
# [65]	train's multi_logloss: 0.901295	train's multi_error: 0.100257	valid's multi_logloss: 1.38554	valid's multi_error: 0.412958
# [70]	train's multi_logloss: 0.855938	train's multi_error: 0.0919523	valid's multi_logloss: 1.35836	valid's multi_error: 0.407723
# [75]	train's multi_logloss: 0.814258	train's multi_error: 0.0836479	valid's multi_logloss: 1.3345	valid's multi_error: 0.407723
# [80]	train's multi_logloss: 0.775149	train's multi_error: 0.0767024	valid's multi_logloss: 1.31319	valid's multi_error: 0.405105
# [85]	train's multi_logloss: 0.739196	train's multi_error: 0.0696059	valid's multi_logloss: 1.29408	valid's multi_error: 0.40445
# [90]	train's multi_logloss: 0.705416	train's multi_error: 0.0629624	valid's multi_logloss: 1.27598	valid's multi_error: 0.403141
# [95]	train's multi_logloss: 0.674244	train's multi_error: 0.0569228	valid's multi_logloss: 1.26055	valid's multi_error: 0.403141
# [100]	train's multi_logloss: 0.645226	train's multi_error: 0.0522422	valid's multi_logloss: 1.24753	valid's multi_error: 0.402487
# [105]	train's multi_logloss: 0.618028	train's multi_error: 0.0463536	valid's multi_logloss: 1.23489	valid's multi_error: 0.401178
# [110]	train's multi_logloss: 0.592107	train's multi_error: 0.040767	valid's multi_logloss: 1.22193	valid's multi_error: 0.401178
# [115]	train's multi_logloss: 0.56825	train's multi_error: 0.0372943	valid's multi_logloss: 1.21123	valid's multi_error: 0.401178
# [120]	train's multi_logloss: 0.545717	train's multi_error: 0.0332176	valid's multi_logloss: 1.2019	valid's multi_error: 0.400524
# [125]	train's multi_logloss: 0.524297	train's multi_error: 0.0301978	valid's multi_logloss: 1.19257	valid's multi_error: 0.39856
# [130]	train's multi_logloss: 0.50411	train's multi_error: 0.026725	valid's multi_logloss: 1.18388	valid's multi_error: 0.395942
# [135]	train's multi_logloss: 0.484861	train's multi_error: 0.0241582	valid's multi_logloss: 1.17645	valid's multi_error: 0.393979
# [140]	train's multi_logloss: 0.466712	train's multi_error: 0.0205345	valid's multi_logloss: 1.16896	valid's multi_error: 0.394634
# [145]	train's multi_logloss: 0.449288	train's multi_error: 0.0187226	valid's multi_logloss: 1.16265	valid's multi_error: 0.393979
# [150]	train's multi_logloss: 0.432956	train's multi_error: 0.0167598	valid's multi_logloss: 1.15632	valid's multi_error: 0.39856
# [155]	train's multi_logloss: 0.417143	train's multi_error: 0.014344	valid's multi_logloss: 1.14951	valid's multi_error: 0.399215
# [160]	train's multi_logloss: 0.402451	train's multi_error: 0.0128341	valid's multi_logloss: 1.14467	valid's multi_error: 0.39856
# [165]	train's multi_logloss: 0.388475	train's multi_error: 0.0113242	valid's multi_logloss: 1.13998	valid's multi_error: 0.395288
# [170]	train's multi_logloss: 0.374856	train's multi_error: 0.00921033	valid's multi_logloss: 1.13516	valid's multi_error: 0.395288
# [175]	train's multi_logloss: 0.362041	train's multi_error: 0.00800242	valid's multi_logloss: 1.13009	valid's multi_error: 0.394634
# [180]	train's multi_logloss: 0.349443	train's multi_error: 0.00724747	valid's multi_logloss: 1.12616	valid's multi_error: 0.396597
# [185]	train's multi_logloss: 0.337609	train's multi_error: 0.00588857	valid's multi_logloss: 1.12324	valid's multi_error: 0.395942
# [190]	train's multi_logloss: 0.326169	train's multi_error: 0.00452967	valid's multi_logloss: 1.11993	valid's multi_error: 0.393979
# [195]	train's multi_logloss: 0.315067	train's multi_error: 0.00362374	valid's multi_logloss: 1.1161	valid's multi_error: 0.396597
# [200]	train's multi_logloss: 0.304785	train's multi_error: 0.00301978	valid's multi_logloss: 1.11241	valid's multi_error: 0.396597
# [205]	train's multi_logloss: 0.294764	train's multi_error: 0.00226483	valid's multi_logloss: 1.10926	valid's multi_error: 0.393325
# [210]	train's multi_logloss: 0.285426	train's multi_error: 0.00181187	valid's multi_logloss: 1.10635	valid's multi_error: 0.391361
# [215]	train's multi_logloss: 0.2763	train's multi_error: 0.00166088	valid's multi_logloss: 1.10416	valid's multi_error: 0.395288
# [220]	train's multi_logloss: 0.267423	train's multi_error: 0.00120791	valid's multi_logloss: 1.1015	valid's multi_error: 0.395942
# [225]	train's multi_logloss: 0.258811	train's multi_error: 0.000754945	valid's multi_logloss: 1.09809	valid's multi_error: 0.396597
# [230]	train's multi_logloss: 0.250728	train's multi_error: 0.000603956	valid's multi_logloss: 1.09547	valid's multi_error: 0.394634
# [235]	train's multi_logloss: 0.242729	train's multi_error: 0.000452967	valid's multi_logloss: 1.0931	valid's multi_error: 0.393325
# [240]	train's multi_logloss: 0.235064	train's multi_error: 0.000452967	valid's multi_logloss: 1.09069	valid's multi_error: 0.390707
# [245]	train's multi_logloss: 0.227708	train's multi_error: 0.000452967	valid's multi_logloss: 1.08861	valid's multi_error: 0.390707
# [250]	train's multi_logloss: 0.220692	train's multi_error: 0.000150989	valid's multi_logloss: 1.08737	valid's multi_error: 0.390707
# [255]	train's multi_logloss: 0.213808	train's multi_error: 0.000150989	valid's multi_logloss: 1.08552	valid's multi_error: 0.390052
# [260]	train's multi_logloss: 0.207132	train's multi_error: 0.000150989	valid's multi_logloss: 1.08382	valid's multi_error: 0.390052
# [265]	train's multi_logloss: 0.200953	train's multi_error: 0.000150989	valid's multi_logloss: 1.08194	valid's multi_error: 0.388089
# [270]	train's multi_logloss: 0.194916	train's multi_error: 0.000150989	valid's multi_logloss: 1.08003	valid's multi_error: 0.388743
# [275]	train's multi_logloss: 0.189117	train's multi_error: 0	valid's multi_logloss: 1.0795	valid's multi_error: 0.390707
# [280]	train's multi_logloss: 0.183407	train's multi_error: 0	valid's multi_logloss: 1.07846	valid's multi_error: 0.389398
# [285]	train's multi_logloss: 0.177897	train's multi_error: 0	valid's multi_logloss: 1.07766	valid's multi_error: 0.387435
# [290]	train's multi_logloss: 0.172606	train's multi_error: 0	valid's multi_logloss: 1.07671	valid's multi_error: 0.388089
# [295]	train's multi_logloss: 0.16734	train's multi_error: 0	valid's multi_logloss: 1.07524	valid's multi_error: 0.388089
# [300]	train's multi_logloss: 0.162414	train's multi_error: 0	valid's multi_logloss: 1.07373	valid's multi_error: 0.388089
# [305]	train's multi_logloss: 0.157625	train's multi_error: 0	valid's multi_logloss: 1.07247	valid's multi_error: 0.390052
# [310]	train's multi_logloss: 0.152961	train's multi_error: 0	valid's multi_logloss: 1.07118	valid's multi_error: 0.38678
# [315]	train's multi_logloss: 0.148382	train's multi_error: 0	valid's multi_logloss: 1.07003	valid's multi_error: 0.384817
# [320]	train's multi_logloss: 0.143902	train's multi_error: 0	valid's multi_logloss: 1.06935	valid's multi_error: 0.385471
# [325]	train's multi_logloss: 0.139569	train's multi_error: 0	valid's multi_logloss: 1.06852	valid's multi_error: 0.383508
# [330]	train's multi_logloss: 0.135367	train's multi_error: 0	valid's multi_logloss: 1.06808	valid's multi_error: 0.385471
# [335]	train's multi_logloss: 0.131444	train's multi_error: 0	valid's multi_logloss: 1.06711	valid's multi_error: 0.384817
# [340]	train's multi_logloss: 0.12757	train's multi_error: 0	valid's multi_logloss: 1.0661	valid's multi_error: 0.382853
# [345]	train's multi_logloss: 0.123854	train's multi_error: 0	valid's multi_logloss: 1.06521	valid's multi_error: 0.384162
# [350]	train's multi_logloss: 0.120196	train's multi_error: 0	valid's multi_logloss: 1.06429	valid's multi_error: 0.384162
# [355]	train's multi_logloss: 0.116724	train's multi_error: 0	valid's multi_logloss: 1.06353	valid's multi_error: 0.382853
# [360]	train's multi_logloss: 0.113308	train's multi_error: 0	valid's multi_logloss: 1.06371	valid's multi_error: 0.383508
# [365]	train's multi_logloss: 0.109925	train's multi_error: 0	valid's multi_logloss: 1.06353	valid's multi_error: 0.383508
# [370]	train's multi_logloss: 0.106692	train's multi_error: 0	valid's multi_logloss: 1.06278	valid's multi_error: 0.385471
# [375]	train's multi_logloss: 0.103668	train's multi_error: 0	valid's multi_logloss: 1.06179	valid's multi_error: 0.384162
# [380]	train's multi_logloss: 0.100705	train's multi_error: 0	valid's multi_logloss: 1.06134	valid's multi_error: 0.382199
# [385]	train's multi_logloss: 0.0977385	train's multi_error: 0	valid's multi_logloss: 1.06119	valid's multi_error: 0.381545
# [390]	train's multi_logloss: 0.0948491	train's multi_error: 0	valid's multi_logloss: 1.06101	valid's multi_error: 0.383508
# [395]	train's multi_logloss: 0.0921137	train's multi_error: 0	valid's multi_logloss: 1.06043	valid's multi_error: 0.384817
# [400]	train's multi_logloss: 0.089442	train's multi_error: 0	valid's multi_logloss: 1.06061	valid's multi_error: 0.384162
# [405]	train's multi_logloss: 0.0869297	train's multi_error: 0	valid's multi_logloss: 1.06038	valid's multi_error: 0.384162
# [410]	train's multi_logloss: 0.0844924	train's multi_error: 0	valid's multi_logloss: 1.05991	valid's multi_error: 0.384162
# [415]	train's multi_logloss: 0.0821458	train's multi_error: 0	valid's multi_logloss: 1.0596	valid's multi_error: 0.383508
# [420]	train's multi_logloss: 0.0798217	train's multi_error: 0	valid's multi_logloss: 1.05902	valid's multi_error: 0.383508
# [425]	train's multi_logloss: 0.077566	train's multi_error: 0	valid's multi_logloss: 1.05923	valid's multi_error: 0.382199
# [430]	train's multi_logloss: 0.0754483	train's multi_error: 0	valid's multi_logloss: 1.05921	valid's multi_error: 0.381545
# [435]	train's multi_logloss: 0.0733611	train's multi_error: 0	valid's multi_logloss: 1.05908	valid's multi_error: 0.38089
# [440]	train's multi_logloss: 0.0713412	train's multi_error: 0	valid's multi_logloss: 1.05903	valid's multi_error: 0.384162
# [445]	train's multi_logloss: 0.0693688	train's multi_error: 0	valid's multi_logloss: 1.05887	valid's multi_error: 0.383508
# [450]	train's multi_logloss: 0.0674564	train's multi_error: 0	valid's multi_logloss: 1.05887	valid's multi_error: 0.383508
# [455]	train's multi_logloss: 0.0655732	train's multi_error: 0	valid's multi_logloss: 1.05926	valid's multi_error: 0.385471
# [460]	train's multi_logloss: 0.0637728	train's multi_error: 0	valid's multi_logloss: 1.05864	valid's multi_error: 0.382853
# [465]	train's multi_logloss: 0.0620267	train's multi_error: 0	valid's multi_logloss: 1.05856	valid's multi_error: 0.382853
# [470]	train's multi_logloss: 0.0603203	train's multi_error: 0	valid's multi_logloss: 1.05821	valid's multi_error: 0.383508
# [475]	train's multi_logloss: 0.0586589	train's multi_error: 0	valid's multi_logloss: 1.05774	valid's multi_error: 0.382199
# [480]	train's multi_logloss: 0.0570449	train's multi_error: 0	valid's multi_logloss: 1.05805	valid's multi_error: 0.380236
# [485]	train's multi_logloss: 0.0554884	train's multi_error: 0	valid's multi_logloss: 1.05766	valid's multi_error: 0.379581
# [490]	train's multi_logloss: 0.0540017	train's multi_error: 0	valid's multi_logloss: 1.05809	valid's multi_error: 0.38089
# [495]	train's multi_logloss: 0.052567	train's multi_error: 0	valid's multi_logloss: 1.05838	valid's multi_error: 0.383508
# [500]	train's multi_logloss: 0.0511534	train's multi_error: 0	valid's multi_logloss: 1.05826	valid's multi_error: 0.383508
# [505]	train's multi_logloss: 0.0498015	train's multi_error: 0	valid's multi_logloss: 1.05847	valid's multi_error: 0.382853
# [510]	train's multi_logloss: 0.0484638	train's multi_error: 0	valid's multi_logloss: 1.05848	valid's multi_error: 0.383508
# [515]	train's multi_logloss: 0.0471779	train's multi_error: 0	valid's multi_logloss: 1.05875	valid's multi_error: 0.38089
# [520]	train's multi_logloss: 0.0459135	train's multi_error: 0	valid's multi_logloss: 1.05923	valid's multi_error: 0.382199
# [525]	train's multi_logloss: 0.0447008	train's multi_error: 0	valid's multi_logloss: 1.05952	valid's multi_error: 0.382199
# [530]	train's multi_logloss: 0.0435293	train's multi_error: 0	valid's multi_logloss: 1.05983	valid's multi_error: 0.382199
# [535]	train's multi_logloss: 0.042388	train's multi_error: 0	valid's multi_logloss: 1.05956	valid's multi_error: 0.382853
# [540]	train's multi_logloss: 0.0412781	train's multi_error: 0	valid's multi_logloss: 1.06039	valid's multi_error: 0.383508
# [545]	train's multi_logloss: 0.0401859	train's multi_error: 0	valid's multi_logloss: 1.06014	valid's multi_error: 0.381545
# [550]	train's multi_logloss: 0.0391405	train's multi_error: 0	valid's multi_logloss: 1.06004	valid's multi_error: 0.380236
# [555]	train's multi_logloss: 0.0381343	train's multi_error: 0	valid's multi_logloss: 1.06026	valid's multi_error: 0.382853
# [560]	train's multi_logloss: 0.0371549	train's multi_error: 0	valid's multi_logloss: 1.0609	valid's multi_error: 0.382853
# [565]	train's multi_logloss: 0.0362196	train's multi_error: 0	valid's multi_logloss: 1.0612	valid's multi_error: 0.383508
# [570]	train's multi_logloss: 0.0352875	train's multi_error: 0	valid's multi_logloss: 1.06157	valid's multi_error: 0.383508
# [575]	train's multi_logloss: 0.0344006	train's multi_error: 0	valid's multi_logloss: 1.0616	valid's multi_error: 0.384162
# [580]	train's multi_logloss: 0.0335207	train's multi_error: 0	valid's multi_logloss: 1.06247	valid's multi_error: 0.384162
# Early stopping, best iteration is:
# [483]	train's multi_logloss: 0.0561107	train's multi_error: 0	valid's multi_logloss: 1.05781	valid's multi_error: 0.378927
# Fold 1 - Competition Score: 0.7579 (Binary F1: 0.9814, Macro F1: 0.5344)
#
# --- Fold 2/5 ---
# Train size: 6519, Val size: 1632
# Training fold 2 with monitoring every 5 rounds (Device: gpu)...
# Training until validation scores don't improve for 100 rounds
# [5]	train's multi_logloss: 2.25535	train's multi_error: 0.350821	valid's multi_logloss: 2.43004	valid's multi_error: 0.596201
# [10]	train's multi_logloss: 1.97111	train's multi_error: 0.274122	valid's multi_logloss: 2.24783	valid's multi_error: 0.564338
# [15]	train's multi_logloss: 1.76483	train's multi_error: 0.240681	valid's multi_logloss: 2.11646	valid's multi_error: 0.539216
# [20]	train's multi_logloss: 1.60071	train's multi_error: 0.217825	valid's multi_logloss: 2.01174	valid's multi_error: 0.526348
# [25]	train's multi_logloss: 1.46644	train's multi_error: 0.198343	valid's multi_logloss: 1.92938	valid's multi_error: 0.515319
# [30]	train's multi_logloss: 1.35256	train's multi_error: 0.183157	valid's multi_logloss: 1.86145	valid's multi_error: 0.508578
# [35]	train's multi_logloss: 1.25509	train's multi_error: 0.166897	valid's multi_logloss: 1.80339	valid's multi_error: 0.504902
# [40]	train's multi_logloss: 1.17057	train's multi_error: 0.152171	valid's multi_logloss: 1.75253	valid's multi_error: 0.5
# [45]	train's multi_logloss: 1.09562	train's multi_error: 0.14174	valid's multi_logloss: 1.70984	valid's multi_error: 0.495098
# [50]	train's multi_logloss: 1.02934	train's multi_error: 0.133149	valid's multi_logloss: 1.67402	valid's multi_error: 0.48652
# [55]	train's multi_logloss: 0.968815	train's multi_error: 0.121951	valid's multi_logloss: 1.64085	valid's multi_error: 0.488971
# [60]	train's multi_logloss: 0.914757	train's multi_error: 0.112441	valid's multi_logloss: 1.61317	valid's multi_error: 0.479779
# [65]	train's multi_logloss: 0.865488	train's multi_error: 0.10201	valid's multi_logloss: 1.58617	valid's multi_error: 0.477941
# [70]	train's multi_logloss: 0.820969	train's multi_error: 0.0934192	valid's multi_logloss: 1.56295	valid's multi_error: 0.474265
# [75]	train's multi_logloss: 0.779582	train's multi_error: 0.0851358	valid's multi_logloss: 1.54343	valid's multi_error: 0.472426
# [80]	train's multi_logloss: 0.74147	train's multi_error: 0.0763921	valid's multi_logloss: 1.52574	valid's multi_error: 0.473039
# [85]	train's multi_logloss: 0.706354	train's multi_error: 0.0685688	valid's multi_logloss: 1.50969	valid's multi_error: 0.469975
# [90]	train's multi_logloss: 0.673538	train's multi_error: 0.0605921	valid's multi_logloss: 1.49533	valid's multi_error: 0.468137
# [95]	train's multi_logloss: 0.643234	train's multi_error: 0.0550698	valid's multi_logloss: 1.48325	valid's multi_error: 0.468137
# [100]	train's multi_logloss: 0.614532	train's multi_error: 0.0487805	valid's multi_logloss: 1.47294	valid's multi_error: 0.458946
# [105]	train's multi_logloss: 0.587661	train's multi_error: 0.0437184	valid's multi_logloss: 1.46276	valid's multi_error: 0.459559
# [110]	train's multi_logloss: 0.562467	train's multi_error: 0.038963	valid's multi_logloss: 1.45177	valid's multi_error: 0.457721
# [115]	train's multi_logloss: 0.539237	train's multi_error: 0.0329805	valid's multi_logloss: 1.44288	valid's multi_error: 0.460784
# [120]	train's multi_logloss: 0.517177	train's multi_error: 0.0308329	valid's multi_logloss: 1.43536	valid's multi_error: 0.456495
# [125]	train's multi_logloss: 0.496614	train's multi_error: 0.0271514	valid's multi_logloss: 1.42767	valid's multi_error: 0.457721
# [130]	train's multi_logloss: 0.476758	train's multi_error: 0.0230097	valid's multi_logloss: 1.42139	valid's multi_error: 0.457108
# [135]	train's multi_logloss: 0.458142	train's multi_error: 0.0200951	valid's multi_logloss: 1.41501	valid's multi_error: 0.457721
# [140]	train's multi_logloss: 0.440502	train's multi_error: 0.0177941	valid's multi_logloss: 1.40855	valid's multi_error: 0.458333
# [145]	train's multi_logloss: 0.423667	train's multi_error: 0.0141126	valid's multi_logloss: 1.40365	valid's multi_error: 0.455882
# [150]	train's multi_logloss: 0.407851	train's multi_error: 0.011965	valid's multi_logloss: 1.39833	valid's multi_error: 0.457108
# [155]	train's multi_logloss: 0.392679	train's multi_error: 0.0110446	valid's multi_logloss: 1.39463	valid's multi_error: 0.456495
# [160]	train's multi_logloss: 0.378004	train's multi_error: 0.00905047	valid's multi_logloss: 1.39072	valid's multi_error: 0.455882
# [165]	train's multi_logloss: 0.364313	train's multi_error: 0.00736309	valid's multi_logloss: 1.38718	valid's multi_error: 0.452206
# [170]	train's multi_logloss: 0.351109	train's multi_error: 0.00644271	valid's multi_logloss: 1.38275	valid's multi_error: 0.458333
# [175]	train's multi_logloss: 0.338632	train's multi_error: 0.00567572	valid's multi_logloss: 1.37935	valid's multi_error: 0.45527
# [180]	train's multi_logloss: 0.326463	train's multi_error: 0.00414174	valid's multi_logloss: 1.3756	valid's multi_error: 0.45527
# [185]	train's multi_logloss: 0.314981	train's multi_error: 0.00245436	valid's multi_logloss: 1.37345	valid's multi_error: 0.452819
# [190]	train's multi_logloss: 0.304187	train's multi_error: 0.00184077	valid's multi_logloss: 1.37013	valid's multi_error: 0.452819
# [195]	train's multi_logloss: 0.293755	train's multi_error: 0.00184077	valid's multi_logloss: 1.36782	valid's multi_error: 0.446078
# [200]	train's multi_logloss: 0.283436	train's multi_error: 0.00153398	valid's multi_logloss: 1.36538	valid's multi_error: 0.445466
# [205]	train's multi_logloss: 0.273863	train's multi_error: 0.00107378	valid's multi_logloss: 1.36241	valid's multi_error: 0.448529
# [210]	train's multi_logloss: 0.264552	train's multi_error: 0.000766989	valid's multi_logloss: 1.36114	valid's multi_error: 0.447917
# [215]	train's multi_logloss: 0.255884	train's multi_error: 0.000613591	valid's multi_logloss: 1.35979	valid's multi_error: 0.448529
# [220]	train's multi_logloss: 0.247256	train's multi_error: 0.000306796	valid's multi_logloss: 1.35834	valid's multi_error: 0.450368
# [225]	train's multi_logloss: 0.239106	train's multi_error: 0.000153398	valid's multi_logloss: 1.35665	valid's multi_error: 0.446691
# [230]	train's multi_logloss: 0.231194	train's multi_error: 0.000153398	valid's multi_logloss: 1.35521	valid's multi_error: 0.450368
# [235]	train's multi_logloss: 0.223595	train's multi_error: 0	valid's multi_logloss: 1.35397	valid's multi_error: 0.452819
# [240]	train's multi_logloss: 0.216332	train's multi_error: 0	valid's multi_logloss: 1.35274	valid's multi_error: 0.449142
# [245]	train's multi_logloss: 0.209333	train's multi_error: 0	valid's multi_logloss: 1.35152	valid's multi_error: 0.448529
# [250]	train's multi_logloss: 0.202457	train's multi_error: 0	valid's multi_logloss: 1.35033	valid's multi_error: 0.449755
# [255]	train's multi_logloss: 0.195993	train's multi_error: 0	valid's multi_logloss: 1.34991	valid's multi_error: 0.45098
# [260]	train's multi_logloss: 0.189795	train's multi_error: 0	valid's multi_logloss: 1.34977	valid's multi_error: 0.448529
# [265]	train's multi_logloss: 0.183745	train's multi_error: 0	valid's multi_logloss: 1.34915	valid's multi_error: 0.449142
# [270]	train's multi_logloss: 0.177997	train's multi_error: 0	valid's multi_logloss: 1.34845	valid's multi_error: 0.449755
# [275]	train's multi_logloss: 0.172338	train's multi_error: 0	valid's multi_logloss: 1.34719	valid's multi_error: 0.446078
# [280]	train's multi_logloss: 0.16673	train's multi_error: 0	valid's multi_logloss: 1.34687	valid's multi_error: 0.446691
# [285]	train's multi_logloss: 0.161569	train's multi_error: 0	valid's multi_logloss: 1.34694	valid's multi_error: 0.445466
# [290]	train's multi_logloss: 0.156518	train's multi_error: 0	valid's multi_logloss: 1.34647	valid's multi_error: 0.446691
# [295]	train's multi_logloss: 0.151635	train's multi_error: 0	valid's multi_logloss: 1.34687	valid's multi_error: 0.446078
# [300]	train's multi_logloss: 0.146935	train's multi_error: 0	valid's multi_logloss: 1.34618	valid's multi_error: 0.445466
# [305]	train's multi_logloss: 0.142492	train's multi_error: 0	valid's multi_logloss: 1.34596	valid's multi_error: 0.445466
# [310]	train's multi_logloss: 0.138154	train's multi_error: 0	valid's multi_logloss: 1.34593	valid's multi_error: 0.443627
# [315]	train's multi_logloss: 0.133796	train's multi_error: 0	valid's multi_logloss: 1.34609	valid's multi_error: 0.446078
# [320]	train's multi_logloss: 0.129735	train's multi_error: 0	valid's multi_logloss: 1.34565	valid's multi_error: 0.446691
# [325]	train's multi_logloss: 0.125759	train's multi_error: 0	valid's multi_logloss: 1.3458	valid's multi_error: 0.446078
# [330]	train's multi_logloss: 0.122011	train's multi_error: 0	valid's multi_logloss: 1.34596	valid's multi_error: 0.443015
# [335]	train's multi_logloss: 0.118367	train's multi_error: 0	valid's multi_logloss: 1.34622	valid's multi_error: 0.443015
# [340]	train's multi_logloss: 0.114754	train's multi_error: 0	valid's multi_logloss: 1.34623	valid's multi_error: 0.441176
# [345]	train's multi_logloss: 0.111278	train's multi_error: 0	valid's multi_logloss: 1.34632	valid's multi_error: 0.442402
# [350]	train's multi_logloss: 0.107944	train's multi_error: 0	valid's multi_logloss: 1.34618	valid's multi_error: 0.445466
# [355]	train's multi_logloss: 0.104604	train's multi_error: 0	valid's multi_logloss: 1.34601	valid's multi_error: 0.445466
# [360]	train's multi_logloss: 0.101452	train's multi_error: 0	valid's multi_logloss: 1.3463	valid's multi_error: 0.443627
# [365]	train's multi_logloss: 0.0984529	train's multi_error: 0	valid's multi_logloss: 1.34698	valid's multi_error: 0.443015
# [370]	train's multi_logloss: 0.0955072	train's multi_error: 0	valid's multi_logloss: 1.34699	valid's multi_error: 0.441176
# [375]	train's multi_logloss: 0.0927448	train's multi_error: 0	valid's multi_logloss: 1.34775	valid's multi_error: 0.441789
# [380]	train's multi_logloss: 0.0900288	train's multi_error: 0	valid's multi_logloss: 1.34751	valid's multi_error: 0.441176
# [385]	train's multi_logloss: 0.0873766	train's multi_error: 0	valid's multi_logloss: 1.34689	valid's multi_error: 0.441789
# [390]	train's multi_logloss: 0.0847632	train's multi_error: 0	valid's multi_logloss: 1.34688	valid's multi_error: 0.443015
# [395]	train's multi_logloss: 0.0823005	train's multi_error: 0	valid's multi_logloss: 1.34691	valid's multi_error: 0.443015
# [400]	train's multi_logloss: 0.0798683	train's multi_error: 0	valid's multi_logloss: 1.34688	valid's multi_error: 0.442402
# [405]	train's multi_logloss: 0.0775034	train's multi_error: 0	valid's multi_logloss: 1.3466	valid's multi_error: 0.443015
# [410]	train's multi_logloss: 0.075239	train's multi_error: 0	valid's multi_logloss: 1.3478	valid's multi_error: 0.443627
# [415]	train's multi_logloss: 0.0730718	train's multi_error: 0	valid's multi_logloss: 1.3479	valid's multi_error: 0.442402
# Early stopping, best iteration is:
# [319]	train's multi_logloss: 0.130542	train's multi_error: 0	valid's multi_logloss: 1.34545	valid's multi_error: 0.444853
# Fold 2 - Competition Score: 0.7098 (Binary F1: 0.9573, Macro F1: 0.4624)
#
# --- Fold 3/5 ---
# Train size: 6526, Val size: 1625
# Training fold 3 with monitoring every 5 rounds (Device: gpu)...
# Training until validation scores don't improve for 100 rounds
# [5]	train's multi_logloss: 2.25916	train's multi_error: 0.349985	valid's multi_logloss: 2.41965	valid's multi_error: 0.593846
# [10]	train's multi_logloss: 1.97703	train's multi_error: 0.275207	valid's multi_logloss: 2.23455	valid's multi_error: 0.552
# [15]	train's multi_logloss: 1.77036	train's multi_error: 0.237358	valid's multi_logloss: 2.10451	valid's multi_error: 0.532923
# [20]	train's multi_logloss: 1.60523	train's multi_error: 0.209623	valid's multi_logloss: 1.99852	valid's multi_error: 0.510769
# [25]	train's multi_logloss: 1.47052	train's multi_error: 0.1943	valid's multi_logloss: 1.91525	valid's multi_error: 0.515692
# [30]	train's multi_logloss: 1.35618	train's multi_error: 0.177291	valid's multi_logloss: 1.8469	valid's multi_error: 0.509538
# [35]	train's multi_logloss: 1.2584	train's multi_error: 0.165798	valid's multi_logloss: 1.78597	valid's multi_error: 0.503385
# [40]	train's multi_logloss: 1.17275	train's multi_error: 0.150781	valid's multi_logloss: 1.73409	valid's multi_error: 0.504
# [45]	train's multi_logloss: 1.09715	train's multi_error: 0.13837	valid's multi_logloss: 1.68997	valid's multi_error: 0.498462
# [50]	train's multi_logloss: 1.02981	train's multi_error: 0.126417	valid's multi_logloss: 1.65264	valid's multi_error: 0.495385
# [55]	train's multi_logloss: 0.969206	train's multi_error: 0.116917	valid's multi_logloss: 1.61779	valid's multi_error: 0.494154
# [60]	train's multi_logloss: 0.914209	train's multi_error: 0.108336	valid's multi_logloss: 1.5887	valid's multi_error: 0.492923
# [65]	train's multi_logloss: 0.864578	train's multi_error: 0.101594	valid's multi_logloss: 1.56262	valid's multi_error: 0.487385
# [70]	train's multi_logloss: 0.819184	train's multi_error: 0.093932	valid's multi_logloss: 1.5402	valid's multi_error: 0.489846
# [75]	train's multi_logloss: 0.777549	train's multi_error: 0.0856574	valid's multi_logloss: 1.51926	valid's multi_error: 0.489846
# [80]	train's multi_logloss: 0.738615	train's multi_error: 0.0761569	valid's multi_logloss: 1.50291	valid's multi_error: 0.486154
# [85]	train's multi_logloss: 0.703425	train's multi_error: 0.0672694	valid's multi_logloss: 1.48664	valid's multi_error: 0.483692
# [90]	train's multi_logloss: 0.670757	train's multi_error: 0.0620595	valid's multi_logloss: 1.4731	valid's multi_error: 0.480615
# [95]	train's multi_logloss: 0.640252	train's multi_error: 0.0548575	valid's multi_logloss: 1.46023	valid's multi_error: 0.480615
# [100]	train's multi_logloss: 0.611568	train's multi_error: 0.0507202	valid's multi_logloss: 1.44894	valid's multi_error: 0.473231
# [105]	train's multi_logloss: 0.585006	train's multi_error: 0.043365	valid's multi_logloss: 1.43874	valid's multi_error: 0.476308
# [110]	train's multi_logloss: 0.560085	train's multi_error: 0.0398406	valid's multi_logloss: 1.4295	valid's multi_error: 0.476923
# [115]	train's multi_logloss: 0.536422	train's multi_error: 0.0320257	valid's multi_logloss: 1.42145	valid's multi_error: 0.474462
# [120]	train's multi_logloss: 0.513815	train's multi_error: 0.0272755	valid's multi_logloss: 1.41284	valid's multi_error: 0.472615
# [125]	train's multi_logloss: 0.492512	train's multi_error: 0.022985	valid's multi_logloss: 1.40604	valid's multi_error: 0.469538
# [130]	train's multi_logloss: 0.472505	train's multi_error: 0.0205333	valid's multi_logloss: 1.39881	valid's multi_error: 0.475692
# [135]	train's multi_logloss: 0.453633	train's multi_error: 0.0174686	valid's multi_logloss: 1.39307	valid's multi_error: 0.473846
# [140]	train's multi_logloss: 0.436011	train's multi_error: 0.0148636	valid's multi_logloss: 1.3876	valid's multi_error: 0.472615
# [145]	train's multi_logloss: 0.419223	train's multi_error: 0.0128716	valid's multi_logloss: 1.38304	valid's multi_error: 0.475077
# [150]	train's multi_logloss: 0.403322	train's multi_error: 0.011186	valid's multi_logloss: 1.37856	valid's multi_error: 0.471385
# [155]	train's multi_logloss: 0.388006	train's multi_error: 0.0104199	valid's multi_logloss: 1.37514	valid's multi_error: 0.472615
# [160]	train's multi_logloss: 0.373674	train's multi_error: 0.00919399	valid's multi_logloss: 1.3717	valid's multi_error: 0.473231
# [165]	train's multi_logloss: 0.360037	train's multi_error: 0.00812136	valid's multi_logloss: 1.36884	valid's multi_error: 0.472
# [170]	train's multi_logloss: 0.347091	train's multi_error: 0.00658903	valid's multi_logloss: 1.3659	valid's multi_error: 0.468308
# [175]	train's multi_logloss: 0.334626	train's multi_error: 0.00566963	valid's multi_logloss: 1.36309	valid's multi_error: 0.468923
# [180]	train's multi_logloss: 0.322796	train's multi_error: 0.00429053	valid's multi_logloss: 1.36059	valid's multi_error: 0.470154
# [185]	train's multi_logloss: 0.311333	train's multi_error: 0.00352436	valid's multi_logloss: 1.35768	valid's multi_error: 0.467077
# [190]	train's multi_logloss: 0.300596	train's multi_error: 0.0027582	valid's multi_logloss: 1.35567	valid's multi_error: 0.464
# [195]	train's multi_logloss: 0.290259	train's multi_error: 0.00199203	valid's multi_logloss: 1.35332	valid's multi_error: 0.464
# [200]	train's multi_logloss: 0.280266	train's multi_error: 0.00153233	valid's multi_logloss: 1.35132	valid's multi_error: 0.462769
# [205]	train's multi_logloss: 0.270721	train's multi_error: 0.000766166	valid's multi_logloss: 1.34965	valid's multi_error: 0.461538
# [210]	train's multi_logloss: 0.261471	train's multi_error: 0.000612933	valid's multi_logloss: 1.34801	valid's multi_error: 0.464
# [215]	train's multi_logloss: 0.252651	train's multi_error: 0.0004597	valid's multi_logloss: 1.3466	valid's multi_error: 0.464
# [220]	train's multi_logloss: 0.24406	train's multi_error: 0.000306466	valid's multi_logloss: 1.34531	valid's multi_error: 0.465231
# [225]	train's multi_logloss: 0.23591	train's multi_error: 0.000306466	valid's multi_logloss: 1.34406	valid's multi_error: 0.466462
# [230]	train's multi_logloss: 0.228166	train's multi_error: 0.000153233	valid's multi_logloss: 1.34274	valid's multi_error: 0.466462
# [235]	train's multi_logloss: 0.22071	train's multi_error: 0	valid's multi_logloss: 1.34118	valid's multi_error: 0.463385
# [240]	train's multi_logloss: 0.213407	train's multi_error: 0	valid's multi_logloss: 1.33978	valid's multi_error: 0.462769
# [245]	train's multi_logloss: 0.20648	train's multi_error: 0	valid's multi_logloss: 1.33818	valid's multi_error: 0.463385
# [250]	train's multi_logloss: 0.199761	train's multi_error: 0	valid's multi_logloss: 1.33754	valid's multi_error: 0.462154
# [255]	train's multi_logloss: 0.193312	train's multi_error: 0	valid's multi_logloss: 1.337	valid's multi_error: 0.464
# [260]	train's multi_logloss: 0.187108	train's multi_error: 0	valid's multi_logloss: 1.33735	valid's multi_error: 0.465231
# [265]	train's multi_logloss: 0.181177	train's multi_error: 0	valid's multi_logloss: 1.33641	valid's multi_error: 0.465846
# [270]	train's multi_logloss: 0.175563	train's multi_error: 0	valid's multi_logloss: 1.33552	valid's multi_error: 0.461538
# [275]	train's multi_logloss: 0.17	train's multi_error: 0	valid's multi_logloss: 1.33447	valid's multi_error: 0.463385
# [280]	train's multi_logloss: 0.164489	train's multi_error: 0	valid's multi_logloss: 1.33375	valid's multi_error: 0.462769
# [285]	train's multi_logloss: 0.15929	train's multi_error: 0	valid's multi_logloss: 1.33324	valid's multi_error: 0.459692
# [290]	train's multi_logloss: 0.154383	train's multi_error: 0	valid's multi_logloss: 1.33204	valid's multi_error: 0.460923
# [295]	train's multi_logloss: 0.149621	train's multi_error: 0	valid's multi_logloss: 1.33206	valid's multi_error: 0.459692
# [300]	train's multi_logloss: 0.145015	train's multi_error: 0	valid's multi_logloss: 1.33215	valid's multi_error: 0.458462
# [305]	train's multi_logloss: 0.140682	train's multi_error: 0	valid's multi_logloss: 1.33285	valid's multi_error: 0.456615
# [310]	train's multi_logloss: 0.136334	train's multi_error: 0	valid's multi_logloss: 1.3326	valid's multi_error: 0.459692
# [315]	train's multi_logloss: 0.132232	train's multi_error: 0	valid's multi_logloss: 1.33284	valid's multi_error: 0.459692
# [320]	train's multi_logloss: 0.128366	train's multi_error: 0	valid's multi_logloss: 1.33276	valid's multi_error: 0.463385
# [325]	train's multi_logloss: 0.124453	train's multi_error: 0	valid's multi_logloss: 1.33358	valid's multi_error: 0.462154
# [330]	train's multi_logloss: 0.120771	train's multi_error: 0	valid's multi_logloss: 1.33353	valid's multi_error: 0.464
# [335]	train's multi_logloss: 0.117117	train's multi_error: 0	valid's multi_logloss: 1.33366	valid's multi_error: 0.463385
# [340]	train's multi_logloss: 0.113582	train's multi_error: 0	valid's multi_logloss: 1.33321	valid's multi_error: 0.462769
# [345]	train's multi_logloss: 0.110226	train's multi_error: 0	valid's multi_logloss: 1.33312	valid's multi_error: 0.461538
# [350]	train's multi_logloss: 0.106868	train's multi_error: 0	valid's multi_logloss: 1.334	valid's multi_error: 0.459077
# [355]	train's multi_logloss: 0.103646	train's multi_error: 0	valid's multi_logloss: 1.33379	valid's multi_error: 0.459692
# [360]	train's multi_logloss: 0.10056	train's multi_error: 0	valid's multi_logloss: 1.33311	valid's multi_error: 0.459692
# [365]	train's multi_logloss: 0.0976057	train's multi_error: 0	valid's multi_logloss: 1.33358	valid's multi_error: 0.460923
# [370]	train's multi_logloss: 0.0946793	train's multi_error: 0	valid's multi_logloss: 1.33432	valid's multi_error: 0.460923
# [375]	train's multi_logloss: 0.0919071	train's multi_error: 0	valid's multi_logloss: 1.3343	valid's multi_error: 0.462154
# [380]	train's multi_logloss: 0.0891892	train's multi_error: 0	valid's multi_logloss: 1.33421	valid's multi_error: 0.458462
# [385]	train's multi_logloss: 0.0865895	train's multi_error: 0	valid's multi_logloss: 1.33509	valid's multi_error: 0.460923
# [390]	train's multi_logloss: 0.0840659	train's multi_error: 0	valid's multi_logloss: 1.33557	valid's multi_error: 0.459077
# Early stopping, best iteration is:
# [292]	train's multi_logloss: 0.152422	train's multi_error: 0	valid's multi_logloss: 1.3319	valid's multi_error: 0.460923
# Fold 3 - Competition Score: 0.7024 (Binary F1: 0.9511, Macro F1: 0.4537)
#
# --- Fold 4/5 ---
# Train size: 6519, Val size: 1632
# Training fold 4 with monitoring every 5 rounds (Device: gpu)...
# Training until validation scores don't improve for 100 rounds
# [5]	train's multi_logloss: 2.25054	train's multi_error: 0.34806	valid's multi_logloss: 2.45113	valid's multi_error: 0.610294
# [10]	train's multi_logloss: 1.96765	train's multi_error: 0.268753	valid's multi_logloss: 2.27512	valid's multi_error: 0.558824
# [15]	train's multi_logloss: 1.76103	train's multi_error: 0.233165	valid's multi_logloss: 2.14728	valid's multi_error: 0.536765
# [20]	train's multi_logloss: 1.59614	train's multi_error: 0.210155	valid's multi_logloss: 2.04603	valid's multi_error: 0.518382
# [25]	train's multi_logloss: 1.46172	train's multi_error: 0.19006	valid's multi_logloss: 1.96314	valid's multi_error: 0.509804
# [30]	train's multi_logloss: 1.34817	train's multi_error: 0.17472	valid's multi_logloss: 1.89411	valid's multi_error: 0.500613
# [35]	train's multi_logloss: 1.25098	train's multi_error: 0.161835	valid's multi_logloss: 1.83622	valid's multi_error: 0.497549
# [40]	train's multi_logloss: 1.16547	train's multi_error: 0.147569	valid's multi_logloss: 1.7856	valid's multi_error: 0.493873
# [45]	train's multi_logloss: 1.09019	train's multi_error: 0.135604	valid's multi_logloss: 1.74286	valid's multi_error: 0.492647
# [50]	train's multi_logloss: 1.02408	train's multi_error: 0.128701	valid's multi_logloss: 1.70554	valid's multi_error: 0.490196
# [55]	train's multi_logloss: 0.963898	train's multi_error: 0.116736	valid's multi_logloss: 1.67203	valid's multi_error: 0.488971
# [60]	train's multi_logloss: 0.909263	train's multi_error: 0.104771	valid's multi_logloss: 1.64038	valid's multi_error: 0.485907
# [65]	train's multi_logloss: 0.859503	train's multi_error: 0.0961804	valid's multi_logloss: 1.61347	valid's multi_error: 0.487745
# [70]	train's multi_logloss: 0.814501	train's multi_error: 0.0886639	valid's multi_logloss: 1.58835	valid's multi_error: 0.487132
# [75]	train's multi_logloss: 0.77333	train's multi_error: 0.0793066	valid's multi_logloss: 1.56697	valid's multi_error: 0.488971
# [80]	train's multi_logloss: 0.734969	train's multi_error: 0.0727105	valid's multi_logloss: 1.5487	valid's multi_error: 0.487132
# [85]	train's multi_logloss: 0.700266	train's multi_error: 0.068262	valid's multi_logloss: 1.52997	valid's multi_error: 0.480392
# [90]	train's multi_logloss: 0.667555	train's multi_error: 0.0630465	valid's multi_logloss: 1.51564	valid's multi_error: 0.477328
# [95]	train's multi_logloss: 0.637074	train's multi_error: 0.0564504	valid's multi_logloss: 1.50304	valid's multi_error: 0.476716
# [100]	train's multi_logloss: 0.608784	train's multi_error: 0.0509281	valid's multi_logloss: 1.49193	valid's multi_error: 0.477328
# [105]	train's multi_logloss: 0.582237	train's multi_error: 0.0464795	valid's multi_logloss: 1.48164	valid's multi_error: 0.479167
# [110]	train's multi_logloss: 0.557146	train's multi_error: 0.03973	valid's multi_logloss: 1.47063	valid's multi_error: 0.47549
# [115]	train's multi_logloss: 0.534218	train's multi_error: 0.0365087	valid's multi_logloss: 1.46227	valid's multi_error: 0.476103
# [120]	train's multi_logloss: 0.512502	train's multi_error: 0.0332873	valid's multi_logloss: 1.45364	valid's multi_error: 0.474877
# [125]	train's multi_logloss: 0.492021	train's multi_error: 0.0297592	valid's multi_logloss: 1.4463	valid's multi_error: 0.476103
# [130]	train's multi_logloss: 0.472529	train's multi_error: 0.024697	valid's multi_logloss: 1.43932	valid's multi_error: 0.474877
# [135]	train's multi_logloss: 0.454012	train's multi_error: 0.0213223	valid's multi_logloss: 1.43233	valid's multi_error: 0.47549
# [140]	train's multi_logloss: 0.436475	train's multi_error: 0.0191747	valid's multi_logloss: 1.42599	valid's multi_error: 0.473652
# [145]	train's multi_logloss: 0.420101	train's multi_error: 0.0159534	valid's multi_logloss: 1.42052	valid's multi_error: 0.471201
# [150]	train's multi_logloss: 0.404435	train's multi_error: 0.0144194	valid's multi_logloss: 1.41455	valid's multi_error: 0.469975
# [155]	train's multi_logloss: 0.389835	train's multi_error: 0.0124252	valid's multi_logloss: 1.40966	valid's multi_error: 0.469975
# [160]	train's multi_logloss: 0.375788	train's multi_error: 0.0108912	valid's multi_logloss: 1.40599	valid's multi_error: 0.467525
# [165]	train's multi_logloss: 0.362088	train's multi_error: 0.00966406	valid's multi_logloss: 1.40197	valid's multi_error: 0.467525
# [170]	train's multi_logloss: 0.349192	train's multi_error: 0.00843688	valid's multi_logloss: 1.3986	valid's multi_error: 0.468137
# [175]	train's multi_logloss: 0.336969	train's multi_error: 0.0069029	valid's multi_logloss: 1.39465	valid's multi_error: 0.467525
# [180]	train's multi_logloss: 0.325323	train's multi_error: 0.00582911	valid's multi_logloss: 1.39258	valid's multi_error: 0.466299
# [185]	train's multi_logloss: 0.314027	train's multi_error: 0.00444854	valid's multi_logloss: 1.38938	valid's multi_error: 0.466299
# [190]	train's multi_logloss: 0.303279	train's multi_error: 0.00368155	valid's multi_logloss: 1.38713	valid's multi_error: 0.466912
# [195]	train's multi_logloss: 0.293013	train's multi_error: 0.00245436	valid's multi_logloss: 1.38478	valid's multi_error: 0.466912
# [200]	train's multi_logloss: 0.282981	train's multi_error: 0.00214757	valid's multi_logloss: 1.38244	valid's multi_error: 0.466912
# [205]	train's multi_logloss: 0.273421	train's multi_error: 0.00153398	valid's multi_logloss: 1.3796	valid's multi_error: 0.466912
# [210]	train's multi_logloss: 0.264119	train's multi_error: 0.00122718	valid's multi_logloss: 1.37739	valid's multi_error: 0.464461
# [215]	train's multi_logloss: 0.255473	train's multi_error: 0.000920387	valid's multi_logloss: 1.37591	valid's multi_error: 0.466299
# [220]	train's multi_logloss: 0.247247	train's multi_error: 0.000920387	valid's multi_logloss: 1.37476	valid's multi_error: 0.465686
# [225]	train's multi_logloss: 0.239159	train's multi_error: 0.000460193	valid's multi_logloss: 1.37297	valid's multi_error: 0.465074
# [230]	train's multi_logloss: 0.231241	train's multi_error: 0.000460193	valid's multi_logloss: 1.37108	valid's multi_error: 0.463848
# [235]	train's multi_logloss: 0.223748	train's multi_error: 0.000306796	valid's multi_logloss: 1.37055	valid's multi_error: 0.464461
# [240]	train's multi_logloss: 0.21644	train's multi_error: 0.000153398	valid's multi_logloss: 1.36965	valid's multi_error: 0.466912
# [245]	train's multi_logloss: 0.20943	train's multi_error: 0.000153398	valid's multi_logloss: 1.3684	valid's multi_error: 0.467525
# [250]	train's multi_logloss: 0.202929	train's multi_error: 0.000153398	valid's multi_logloss: 1.3671	valid's multi_error: 0.464461
# [255]	train's multi_logloss: 0.196454	train's multi_error: 0	valid's multi_logloss: 1.36622	valid's multi_error: 0.466912
# [260]	train's multi_logloss: 0.190219	train's multi_error: 0	valid's multi_logloss: 1.3659	valid's multi_error: 0.467525
# [265]	train's multi_logloss: 0.184111	train's multi_error: 0	valid's multi_logloss: 1.36488	valid's multi_error: 0.469363
# [270]	train's multi_logloss: 0.178177	train's multi_error: 0	valid's multi_logloss: 1.36364	valid's multi_error: 0.46875
# [275]	train's multi_logloss: 0.172531	train's multi_error: 0	valid's multi_logloss: 1.36314	valid's multi_error: 0.469363
# [280]	train's multi_logloss: 0.167128	train's multi_error: 0	valid's multi_logloss: 1.36294	valid's multi_error: 0.469975
# [285]	train's multi_logloss: 0.161826	train's multi_error: 0	valid's multi_logloss: 1.3622	valid's multi_error: 0.471814
# [290]	train's multi_logloss: 0.156748	train's multi_error: 0	valid's multi_logloss: 1.36164	valid's multi_error: 0.469975
# [295]	train's multi_logloss: 0.151847	train's multi_error: 0	valid's multi_logloss: 1.36115	valid's multi_error: 0.471201
# [300]	train's multi_logloss: 0.14716	train's multi_error: 0	valid's multi_logloss: 1.36047	valid's multi_error: 0.474877
# [305]	train's multi_logloss: 0.142697	train's multi_error: 0	valid's multi_logloss: 1.36007	valid's multi_error: 0.471201
# [310]	train's multi_logloss: 0.138368	train's multi_error: 0	valid's multi_logloss: 1.35995	valid's multi_error: 0.470588
# [315]	train's multi_logloss: 0.134125	train's multi_error: 0	valid's multi_logloss: 1.35974	valid's multi_error: 0.469363
# [320]	train's multi_logloss: 0.130107	train's multi_error: 0	valid's multi_logloss: 1.3592	valid's multi_error: 0.469975
# [325]	train's multi_logloss: 0.12615	train's multi_error: 0	valid's multi_logloss: 1.35953	valid's multi_error: 0.468137
# [330]	train's multi_logloss: 0.122209	train's multi_error: 0	valid's multi_logloss: 1.35935	valid's multi_error: 0.468137
# Early stopping, best iteration is:
# [234]	train's multi_logloss: 0.225258	train's multi_error: 0.000306796	valid's multi_logloss: 1.37075	valid's multi_error: 0.462623
# Fold 4 - Competition Score: 0.7080 (Binary F1: 0.9478, Macro F1: 0.4683)
#
# --- Fold 5/5 ---
# Train size: 6417, Val size: 1734
# Training fold 5 with monitoring every 5 rounds (Device: gpu)...
# Training until validation scores don't improve for 100 rounds
# [5]	train's multi_logloss: 2.25556	train's multi_error: 0.348294	valid's multi_logloss: 2.43474	valid's multi_error: 0.60323
# [10]	train's multi_logloss: 1.97137	train's multi_error: 0.280193	valid's multi_logloss: 2.25402	valid's multi_error: 0.56113
# [15]	train's multi_logloss: 1.76535	train's multi_error: 0.243416	valid's multi_logloss: 2.12475	valid's multi_error: 0.551903
# [20]	train's multi_logloss: 1.6007	train's multi_error: 0.217235	valid's multi_logloss: 2.02258	valid's multi_error: 0.541522
# [25]	train's multi_logloss: 1.46614	train's multi_error: 0.197756	valid's multi_logloss: 1.93844	valid's multi_error: 0.525952
# [30]	train's multi_logloss: 1.35074	train's multi_error: 0.181393	valid's multi_logloss: 1.86795	valid's multi_error: 0.517878
# [35]	train's multi_logloss: 1.25254	train's multi_error: 0.16503	valid's multi_logloss: 1.81059	valid's multi_error: 0.515571
# [40]	train's multi_logloss: 1.16792	train's multi_error: 0.152408	valid's multi_logloss: 1.76126	valid's multi_error: 0.50692
# [45]	train's multi_logloss: 1.09301	train's multi_error: 0.141032	valid's multi_logloss: 1.71823	valid's multi_error: 0.504037
# [50]	train's multi_logloss: 1.02615	train's multi_error: 0.1295	valid's multi_logloss: 1.68192	valid's multi_error: 0.5
# [55]	train's multi_logloss: 0.965919	train's multi_error: 0.119994	valid's multi_logloss: 1.6487	valid's multi_error: 0.49654
# [60]	train's multi_logloss: 0.911357	train's multi_error: 0.110644	valid's multi_logloss: 1.62021	valid's multi_error: 0.499423
# [65]	train's multi_logloss: 0.86181	train's multi_error: 0.100826	valid's multi_logloss: 1.59505	valid's multi_error: 0.500577
# [70]	train's multi_logloss: 0.816456	train's multi_error: 0.0933458	valid's multi_logloss: 1.57226	valid's multi_error: 0.495386
# [75]	train's multi_logloss: 0.775359	train's multi_error: 0.0852423	valid's multi_logloss: 1.55089	valid's multi_error: 0.489043
# [80]	train's multi_logloss: 0.737155	train's multi_error: 0.0782297	valid's multi_logloss: 1.53378	valid's multi_error: 0.487313
# [85]	train's multi_logloss: 0.701867	train's multi_error: 0.0702821	valid's multi_logloss: 1.5188	valid's multi_error: 0.483852
# [90]	train's multi_logloss: 0.669562	train's multi_error: 0.0637369	valid's multi_logloss: 1.50395	valid's multi_error: 0.481546
# [95]	train's multi_logloss: 0.639009	train's multi_error: 0.0585944	valid's multi_logloss: 1.49083	valid's multi_error: 0.479239
# [100]	train's multi_logloss: 0.610991	train's multi_error: 0.0525168	valid's multi_logloss: 1.47941	valid's multi_error: 0.479815
# [105]	train's multi_logloss: 0.58438	train's multi_error: 0.0470625	valid's multi_logloss: 1.46761	valid's multi_error: 0.478662
# [110]	train's multi_logloss: 0.559205	train's multi_error: 0.0425432	valid's multi_logloss: 1.45785	valid's multi_error: 0.474625
# [115]	train's multi_logloss: 0.535477	train's multi_error: 0.038024	valid's multi_logloss: 1.44899	valid's multi_error: 0.472895
# [120]	train's multi_logloss: 0.513242	train's multi_error: 0.0335048	valid's multi_logloss: 1.44099	valid's multi_error: 0.471742
# [125]	train's multi_logloss: 0.492317	train's multi_error: 0.0300764	valid's multi_logloss: 1.43431	valid's multi_error: 0.468858
# [130]	train's multi_logloss: 0.472764	train's multi_error: 0.0261805	valid's multi_logloss: 1.42725	valid's multi_error: 0.469435
# [135]	train's multi_logloss: 0.454074	train's multi_error: 0.0224404	valid's multi_logloss: 1.42097	valid's multi_error: 0.470012
# [140]	train's multi_logloss: 0.436514	train's multi_error: 0.0194795	valid's multi_logloss: 1.41605	valid's multi_error: 0.470012
# [145]	train's multi_logloss: 0.419975	train's multi_error: 0.0168303	valid's multi_logloss: 1.41108	valid's multi_error: 0.470588
# [150]	train's multi_logloss: 0.403994	train's multi_error: 0.0148044	valid's multi_logloss: 1.406	valid's multi_error: 0.467705
# [155]	train's multi_logloss: 0.389341	train's multi_error: 0.0130902	valid's multi_logloss: 1.40262	valid's multi_error: 0.464245
# [160]	train's multi_logloss: 0.374801	train's multi_error: 0.0112202	valid's multi_logloss: 1.39908	valid's multi_error: 0.467705
# [165]	train's multi_logloss: 0.361372	train's multi_error: 0.00903849	valid's multi_logloss: 1.39564	valid's multi_error: 0.464821
# [170]	train's multi_logloss: 0.348113	train's multi_error: 0.00748013	valid's multi_logloss: 1.39355	valid's multi_error: 0.461938
# [175]	train's multi_logloss: 0.335831	train's multi_error: 0.00576593	valid's multi_logloss: 1.39131	valid's multi_error: 0.465398
# [180]	train's multi_logloss: 0.323924	train's multi_error: 0.00483092	valid's multi_logloss: 1.38874	valid's multi_error: 0.463668
# [185]	train's multi_logloss: 0.312791	train's multi_error: 0.00436341	valid's multi_logloss: 1.38668	valid's multi_error: 0.464821
# [190]	train's multi_logloss: 0.301882	train's multi_error: 0.00342839	valid's multi_logloss: 1.38471	valid's multi_error: 0.466551
# [195]	train's multi_logloss: 0.291486	train's multi_error: 0.00342839	valid's multi_logloss: 1.38289	valid's multi_error: 0.462514
# [200]	train's multi_logloss: 0.281525	train's multi_error: 0.00280505	valid's multi_logloss: 1.38029	valid's multi_error: 0.463091
# [205]	train's multi_logloss: 0.272003	train's multi_error: 0.0021817	valid's multi_logloss: 1.37861	valid's multi_error: 0.463091
# [210]	train's multi_logloss: 0.262617	train's multi_error: 0.00155836	valid's multi_logloss: 1.37656	valid's multi_error: 0.459054
# [215]	train's multi_logloss: 0.254001	train's multi_error: 0.00140252	valid's multi_logloss: 1.37496	valid's multi_error: 0.461361
# [220]	train's multi_logloss: 0.245479	train's multi_error: 0.000935016	valid's multi_logloss: 1.37351	valid's multi_error: 0.460208
# [225]	train's multi_logloss: 0.237075	train's multi_error: 0.00077918	valid's multi_logloss: 1.37154	valid's multi_error: 0.460784
# [230]	train's multi_logloss: 0.229353	train's multi_error: 0.00077918	valid's multi_logloss: 1.37021	valid's multi_error: 0.460784
# [235]	train's multi_logloss: 0.221821	train's multi_error: 0.000623344	valid's multi_logloss: 1.36912	valid's multi_error: 0.460208
# [240]	train's multi_logloss: 0.214524	train's multi_error: 0.000623344	valid's multi_logloss: 1.36751	valid's multi_error: 0.457324
# [245]	train's multi_logloss: 0.20753	train's multi_error: 0.000467508	valid's multi_logloss: 1.36696	valid's multi_error: 0.455594
# [250]	train's multi_logloss: 0.20073	train's multi_error: 0.000311672	valid's multi_logloss: 1.36663	valid's multi_error: 0.455017
# [255]	train's multi_logloss: 0.194436	train's multi_error: 0.000155836	valid's multi_logloss: 1.3664	valid's multi_error: 0.453287
# [260]	train's multi_logloss: 0.187993	train's multi_error: 0.000155836	valid's multi_logloss: 1.3655	valid's multi_error: 0.45271
# [265]	train's multi_logloss: 0.181947	train's multi_error: 0.000155836	valid's multi_logloss: 1.36548	valid's multi_error: 0.451557
# [270]	train's multi_logloss: 0.176206	train's multi_error: 0.000155836	valid's multi_logloss: 1.3655	valid's multi_error: 0.451557
# [275]	train's multi_logloss: 0.170569	train's multi_error: 0.000155836	valid's multi_logloss: 1.36475	valid's multi_error: 0.453864
# [280]	train's multi_logloss: 0.165107	train's multi_error: 0.000155836	valid's multi_logloss: 1.36404	valid's multi_error: 0.454441
# [285]	train's multi_logloss: 0.159911	train's multi_error: 0.000155836	valid's multi_logloss: 1.36467	valid's multi_error: 0.453864
# [290]	train's multi_logloss: 0.154935	train's multi_error: 0	valid's multi_logloss: 1.36425	valid's multi_error: 0.453287
# [295]	train's multi_logloss: 0.150116	train's multi_error: 0	valid's multi_logloss: 1.3642	valid's multi_error: 0.45098
# [300]	train's multi_logloss: 0.145287	train's multi_error: 0	valid's multi_logloss: 1.36378	valid's multi_error: 0.45098
# [305]	train's multi_logloss: 0.140703	train's multi_error: 0	valid's multi_logloss: 1.36364	valid's multi_error: 0.452134
# [310]	train's multi_logloss: 0.136556	train's multi_error: 0	valid's multi_logloss: 1.36393	valid's multi_error: 0.450404
# [315]	train's multi_logloss: 0.132322	train's multi_error: 0	valid's multi_logloss: 1.36343	valid's multi_error: 0.449827
# [320]	train's multi_logloss: 0.128288	train's multi_error: 0	valid's multi_logloss: 1.36311	valid's multi_error: 0.448097
# [325]	train's multi_logloss: 0.124313	train's multi_error: 0	valid's multi_logloss: 1.36247	valid's multi_error: 0.445213
# [330]	train's multi_logloss: 0.120563	train's multi_error: 0	valid's multi_logloss: 1.36321	valid's multi_error: 0.446943
# [335]	train's multi_logloss: 0.116842	train's multi_error: 0	valid's multi_logloss: 1.36213	valid's multi_error: 0.446943
# [340]	train's multi_logloss: 0.113317	train's multi_error: 0	valid's multi_logloss: 1.36176	valid's multi_error: 0.446367
# [345]	train's multi_logloss: 0.109909	train's multi_error: 0	valid's multi_logloss: 1.36063	valid's multi_error: 0.44752
# [350]	train's multi_logloss: 0.106541	train's multi_error: 0	valid's multi_logloss: 1.36016	valid's multi_error: 0.446367
# [355]	train's multi_logloss: 0.103354	train's multi_error: 0	valid's multi_logloss: 1.36076	valid's multi_error: 0.446943
# [360]	train's multi_logloss: 0.100266	train's multi_error: 0	valid's multi_logloss: 1.36016	valid's multi_error: 0.446943
# [365]	train's multi_logloss: 0.0971889	train's multi_error: 0	valid's multi_logloss: 1.36047	valid's multi_error: 0.444637
# [370]	train's multi_logloss: 0.094281	train's multi_error: 0	valid's multi_logloss: 1.36019	valid's multi_error: 0.446367
# [375]	train's multi_logloss: 0.0914611	train's multi_error: 0	valid's multi_logloss: 1.35982	valid's multi_error: 0.444637
# [380]	train's multi_logloss: 0.0887997	train's multi_error: 0	valid's multi_logloss: 1.3598	valid's multi_error: 0.44406
# [385]	train's multi_logloss: 0.0861932	train's multi_error: 0	valid's multi_logloss: 1.35992	valid's multi_error: 0.442907
# [390]	train's multi_logloss: 0.0836133	train's multi_error: 0	valid's multi_logloss: 1.36076	valid's multi_error: 0.444637
# [395]	train's multi_logloss: 0.0811139	train's multi_error: 0	valid's multi_logloss: 1.36045	valid's multi_error: 0.443483
# [400]	train's multi_logloss: 0.0787129	train's multi_error: 0	valid's multi_logloss: 1.36035	valid's multi_error: 0.443483
# [405]	train's multi_logloss: 0.0764001	train's multi_error: 0	valid's multi_logloss: 1.36068	valid's multi_error: 0.44233
# [410]	train's multi_logloss: 0.0741589	train's multi_error: 0	valid's multi_logloss: 1.36139	valid's multi_error: 0.44233
# [415]	train's multi_logloss: 0.071969	train's multi_error: 0	valid's multi_logloss: 1.36157	valid's multi_error: 0.44233
# [420]	train's multi_logloss: 0.0698279	train's multi_error: 0	valid's multi_logloss: 1.3618	valid's multi_error: 0.444637
# [425]	train's multi_logloss: 0.0677417	train's multi_error: 0	valid's multi_logloss: 1.36289	valid's multi_error: 0.446367
# [430]	train's multi_logloss: 0.0658199	train's multi_error: 0	valid's multi_logloss: 1.36261	valid's multi_error: 0.443483
# [435]	train's multi_logloss: 0.0639688	train's multi_error: 0	valid's multi_logloss: 1.36282	valid's multi_error: 0.44406
# [440]	train's multi_logloss: 0.0621293	train's multi_error: 0	valid's multi_logloss: 1.36265	valid's multi_error: 0.44406
# [445]	train's multi_logloss: 0.0603141	train's multi_error: 0	valid's multi_logloss: 1.36314	valid's multi_error: 0.446367
# [450]	train's multi_logloss: 0.0585882	train's multi_error: 0	valid's multi_logloss: 1.36365	valid's multi_error: 0.444637
# [455]	train's multi_logloss: 0.0569143	train's multi_error: 0	valid's multi_logloss: 1.36428	valid's multi_error: 0.44579
# [460]	train's multi_logloss: 0.0552874	train's multi_error: 0	valid's multi_logloss: 1.36458	valid's multi_error: 0.445213
# [465]	train's multi_logloss: 0.0537149	train's multi_error: 0	valid's multi_logloss: 1.36506	valid's multi_error: 0.44406
# [470]	train's multi_logloss: 0.0522002	train's multi_error: 0	valid's multi_logloss: 1.36574	valid's multi_error: 0.442907
# [475]	train's multi_logloss: 0.0507079	train's multi_error: 0	valid's multi_logloss: 1.36622	valid's multi_error: 0.44406
# [480]	train's multi_logloss: 0.049239	train's multi_error: 0	valid's multi_logloss: 1.36653	valid's multi_error: 0.442907
# Early stopping, best iteration is:
# [382]	train's multi_logloss: 0.0877394	train's multi_error: 0	valid's multi_logloss: 1.35963	valid's multi_error: 0.443483
# Fold 5 - Competition Score: 0.7203 (Binary F1: 0.9540, Macro F1: 0.4866)
#
# ============================================================
# CROSS-VALIDATION RESULTS
# ============================================================
# Overall Competition Score: 0.7193 ± 0.0200
# Overall Binary F1: 0.9579
# Overall Macro F1: 0.4807
# Fold scores: ['0.7579', '0.7098', '0.7024', '0.7080', '0.7203']
# ============================================================
#
# ✓ Training completed successfully!
# ✓ Final CV Score: 0.7193
# ✓ Core innovation: World acceleration transformation
# ✓ Models ready for inference
#
# Setting up inference server...
# Predicted: Eyelash - pull hair (class 3)
# Predicted: Eyebrow - pull hair (class 2)
